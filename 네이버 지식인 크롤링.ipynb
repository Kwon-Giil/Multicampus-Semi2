# %%
from selenium import webdriver
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select
import numpy as np
from tqdm.notebook import tqdm
import re

# %%
url = 'https://kin.naver.com/qna/expertAnswerList.naver?dirId=60221&queryTime=2022-05-31%2000%3A40%3A19&page='

# %%
html = requests.get(url)
soup = bs(html.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="민사소송의 질문 목록을 볼 수 있습니다." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/people.css" rel="stylesheet" type="text/css">
# <style type="text/css">
# .board_box {width:629px; padding:0 25px 44px 25px; background:url(https://ssl.pstatic.net/static/kin/09renewal/bg_table_top.gif) repeat-x top;}
#
# .boardtype2 tbody td.result_no {font-weight:bold; font-size:12px; color:#303030; text-align:center; padding:96px 0 96px;}
# .board_box .boardtype2 tbody td.result_no {padding-top:86px;}
# </style>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="민사소송 분야 법률 전문가 답변 질문 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=2" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="민사소송의 질문 목록을 볼 수 있습니다." property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.2" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	민사소송 분야 법률 전문가 답변 질문 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = true;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min';
#
# var g_ssc = ("kin.list" == "") ? "kin.temp" : "kin.list";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
# </script>
# </meta></meta></link></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_qna" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#contentsOfQna" onclick="nhn.Kin.Utility.skipNavigation('contentsOfQna');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="logo_kin sp_common">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="sp_gnb icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);">지식iN</a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value=""/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_chat _chatButtonArea">
# <button aria-controls="chatMenu" aria-expanded="false" aria-haspopup="true" aria-pressed="false" class="button_chat" id="chatButton" type="button">
# <span class="blind">상담 목록</span>
# <span class="icon_chat"></span>
# <i class="icon_new" style="display: none"><span class="blind">NEW</span></i>
# </button>
# <div aria-hidden="true" class="chat_popup" id="chatMenu" role="menu">
# <a class="link_chat" href="/expert/center/counseling/list" role="menuitem" target="_blank">
# 								판매한 상품
# 								<i class="_counselorNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# <a class="link_chat" href="/counseling/purchases" role="menuitem" target="_blank">
# 								구매한 상품
# 								<i class="_counseleeNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# </div>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2022053100" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">전문가라면 엑스퍼트로 모십니다.</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner _containerFluidContentInner">
# <strong class="blind">현재 페이지 경로</strong>
# <ul class="location" id="au_location">
# <li>
# <a class="_nclicks:drb.qa" href="/qna/list.naver">Q&amp;A</a>
# <a class="more _lookUpChildElement('img')" href="#"><img alt="더보기" class="_nclicks:drb.qalayeropen,r:0,i:0" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="12"/></a>
# </li>
# <li>
# <a class="_nclicks:drb.depth1,r:2,i:6" href="/qna/list.naver?dirId=6">사회, 정치</a>
# <a class="more _lookUpChildElement('img')" href="#"><img alt="더보기" class="_nclicks:drb.qalayeropen,r:1,i:6" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="12"/></a>
# <div class="sub">
# <ul>
# <li><a class="_nclicks:drb.qalayer,r:1,i:11" href="/qna/list.naver?dirId=11">교육, 학문</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:2,i:1" href="/qna/list.naver?dirId=1">컴퓨터통신</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:3,i:2" href="/qna/list.naver?dirId=2">게임</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:4,i:3" href="/qna/list.naver?dirId=3">엔터테인먼트, 예술</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:5,i:8" href="/qna/list.naver?dirId=8">생활</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:6,i:7" href="/qna/list.naver?dirId=7">건강</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:7,i:6" href="/qna/list.naver?dirId=6">사회, 정치</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:8,i:4" href="/qna/list.naver?dirId=4">경제</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:9,i:9" href="/qna/list.naver?dirId=9">여행</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:10,i:10" href="/qna/list.naver?dirId=10">스포츠, 레저</a></li>
# <li><a class="_nclicks:drb.depth1layer,r:11,i:5" href="/qna/list.naver?dirId=5">쇼핑</a></li>
# </ul>
# </div>
# <iframe frameborder="0" scrolling="no" style="margin:20px 0px 0px -6px;height:50px;left:0;position:absolute;top:0;width:50px;z-index:-1;display:none;" title="내용없음"></iframe>
# </li>
# <li>
# <a class="_nclicks:drb.depth2,r:3,i:602" href="/qna/list.naver?dirId=602">법, 법률</a>
# <a class="more _lookUpChildElement('img')" href="#"><img alt="더보기" class="_nclicks:drb.qalayeropen,r:2,i:602" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="12"/></a>
# <div class="sub">
# <ul>
# <li><a class="_nclicks:drb.qalayer,r:1,i:601" href="/qna/list.naver?dirId=601">민원, 행정</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:2,i:602" href="/qna/list.naver?dirId=602">법, 법률</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:3,i:603" href="/qna/list.naver?dirId=603">병역</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:4,i:604" href="/qna/list.naver?dirId=604">국방</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:5,i:605" href="/qna/list.naver?dirId=605">외교</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:6,i:606" href="/qna/list.naver?dirId=606">통일</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:7,i:607" href="/qna/list.naver?dirId=607">선거</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:8,i:608" href="/qna/list.naver?dirId=608">고용, 노동</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:9,i:609" href="/qna/list.naver?dirId=609">종교</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:10,i:610" href="/qna/list.naver?dirId=610">복지</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:11,i:611" href="/qna/list.naver?dirId=611">환경</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:12,i:612" href="/qna/list.naver?dirId=612">재난재해</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:13,i:613" href="/qna/list.naver?dirId=613">사회문화</a></li>
# <li><a class="_nclicks:drb.depth2layer,r:14,i:614" href="/qna/list.naver?dirId=614">기관, 단체, 인물</a></li>
# </ul>
# </div>
# <iframe frameborder="0" scrolling="no" style="margin:20px 0px 0px -6px;height:50px;left:0;position:absolute;top:0;width:50px;z-index:-1;display:none;" title="내용없음"></iframe>
# </li>
# <li class="last">
# <a class="_nclicks:drb.depth3,r:4,i:60221" href="/qna/list.naver?dirId=60221">민사소송</a>
# <a class="more _lookUpChildElement('img')" href="#"><img alt="더보기" class="_nclicks:drb.qalayeropen,r:3,i:60221" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="12"/></a>
# <div class="sub">
# <ul class="scroll">
# <li><a class="_nclicks:drb.qalayer,r:1,i:60201" href="/qna/list.naver?dirId=60201">교통 사고, 위반</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:2,i:60202" href="/qna/list.naver?dirId=60202">부동산, 건축</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:3,i:60203" href="/qna/list.naver?dirId=60203">신용, 파산</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:4,i:60204" href="/qna/list.naver?dirId=60204">가족, 이혼</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:5,i:60205" href="/qna/list.naver?dirId=60205">지식재산권</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:6,i:60206" href="/qna/list.naver?dirId=60206">형사사건</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:7,i:60207" href="/qna/list.naver?dirId=60207">소비자관련법, 상법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:8,i:60208" href="/qna/list.naver?dirId=60208">청소년관련법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:9,i:60209" href="/qna/list.naver?dirId=403">@ 세금, 세무</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:10,i:60211" href="/qna/list.naver?dirId=60211">재판, 소송 절차</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:11,i:60212" href="/qna/list.naver?dirId=60212">계약</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:12,i:60213" href="/qna/list.naver?dirId=60213">손해배상</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:13,i:60214" href="/qna/list.naver?dirId=60214">형벌, 형집행</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:14,i:60215" href="/qna/list.naver?dirId=60215">법학, 법이론</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:15,i:60216" href="/qna/list.naver?dirId=60216">언론, 미디어 관련법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:16,i:60217" href="/qna/list.naver?dirId=60217">외국법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:17,i:60218" href="/qna/list.naver?dirId=60218">헌법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:18,i:60219" href="/qna/list.naver?dirId=60219">행정법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:19,i:60220" href="/qna/list.naver?dirId=60220">민법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:20,i:60221" href="/qna/list.naver?dirId=60221">민사소송</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:21,i:60222" href="/qna/list.naver?dirId=60222">노동법</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:22,i:60223" href="/qna/list.naver?dirId=60223">등기</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:23,i:60224" href="/qna/list.naver?dirId=60224">민사집행</a></li>
# <li><a class="_nclicks:drb.depth3layer,r:24,i:60225" href="/qna/list.naver?dirId=60225">산업재해</a></li>
# </ul>
# </div>
# <iframe frameborder="0" scrolling="no" style="margin:20px 0px 0px -6px;height:50px;left:0;position:absolute;top:0;width:50px;z-index:-1;display:none;" title="내용없음"></iframe>
# </li>
# <li class="alt _btn_add_area"><a class="_ros _clickcode:drb.add" href="#" id="au_add_directory" target="_blank"><img alt="관심분야 추가" dirid="60221" height="18" src="https://ssl.pstatic.net/static/kin/09renewal/btn_add_short.gif" width="18"/></a>
# </li>
# </ul>
# <style type="text/css">
# .banner_kincommon {position:relative; float:right; width:190px; margin:-40px 0 0 0; z-index:23;}
# .banner_kincommon img {vertical-align:top;}
# </style>
# <div class="container-fluid-content__left" id="content">
# <div class="spot_area">
# <div class="spot_area_inner">
# <div class="s_header">
# <h2>민사소송</h2>
# <div class="ques_cnt">
# <dl>
# <dt class="itm">오늘의 새 질문</dt>
# <dd id="todayQuestion">2</dd>
# <dt class="itm2">모바일 질문</dt>
# <dd id="todayMobileQuestion">2</dd>
# <dt class="itm3">오늘의 답변</dt>
# <dd id="todayAnswer">0</dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# $Fn(function() {
# 	nhn.Kin.Utility.startRollingCount($("todayQuestion"), 2, $("todayMobileQuestion"), 2, $("todayAnswer"), 0);
# }).attach(document, "domready");
# </script>
# <!-- 배너 시작 -->
# <!-- 디렉토리에디터 모집 배너 -->
# <!-- //디렉토리에디터 모집 배너 -->
# <!-- 배너 끝 -->
# <div class="kinqna_wp _kinqna_wp">
# <ul class="tab1 tab1_box" role="tablist">
# <li role="presentation">
# <a aria-selected="false" class="item _nclicks:kls.new" href="/qna/list.naver?dirId=60221" id="contentsOfQna" role="tab" tabindex="-1">질문</a>
# </li>
# <!-- [KINSUS-31195] Q&A나 전문가답변 질문목록 Tab은 목록이 비어있는지 체크하지 않고 항상 노출한다. (성능 이슈) -->
# <li class="on" role="presentation">
# <a aria-selected="true" class="item" href="/qna/expertAnswerList.naver?dirId=60221" role="tab" tabindex="-1">법률 전문가 답변 질문</a>
# </li>
# <li role="presentation">
# <a aria-selected="false" class="item _nclicks:kls.expert" href="/qna/directoryExpertList.naver?dirId=60221" role="tab" tabindex="-1">랭킹</a>
# </li>
# </ul>
# </div>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/naver.kin.QnaEnd.Tab.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	if (typeof naver.kin.QnaEnd.Tab !== 'undefined') {
# 		var oQnaEndTab = new naver.kin.QnaEnd.Tab();
# 	}
# </script>
# <div class="qna_list_expertAnswer" id="list_expertAnswer">
# <div class="board_box">
# <h3 class="blind">전문가 질문/답변 게시판</h3>
# <table cellspacing="0" class="boardtype2" width="100%">
# <caption><span class="blind">전문가 질문 게시글 2페이지 목록</span></caption>
# <colgroup>
# <col/>
# <col width="94"/>
# <col width="96"/>
# <col width="48"/>
# </colgroup>
# <thead>
# <tr>
# <!-- 정렬 기준 선택할때마다 up/down 클래스 변경 -->
# <th class="title" scope="col">제목</th>
# <th scope="col">분야</th>
# <th scope="col">작성자</th>
# <th class="on" scope="col"><a href="/qna/expertAnswerList.naver?sort=answerTime&amp;dirId=60221">작성<img alt="정렬" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="12"/></a></th>
# </tr>
# </thead>
# <tbody id="au_board_list">
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420601847" rel="KIN">부당이득금 등기이전 관련</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('pearledmars')" href="/profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6CBqCVDPBff3XAaGxicyr3Y%3D">이종걸</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">13시간 전</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420599468" rel="KIN">민사소송 질문드립니다.</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('hunbubsuho')" href="/profile/index.naver?u=m%2BssEnLiDz%2FaXEoGRliZ97Jk9Cn%2B8mVBCU7XrQBJkSA%3D">김호제</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">14시간 전</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420590184" rel="KIN">고소 고민</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('law3149')" href="/profile/index.naver?u=dEgr29uBZ5z0sTY%2FIic1U8r4rT%2BfX97EC6sMbz2os5Q%3D">이재호</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">17시간 전</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420529301" rel="KIN">모욕죄 민사 조정</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('tongkwon2')" href="/profile/index.naver?u=vWlXGDBdOqyyM9ZZj5apMuUJWtcX5NndIARjqyYdUY0%3D">유성권</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420526293" rel="KIN">대여금반환청구소송에 있어서 차용증(약정서), 카톡기록 등이 다...</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('tongkwon2')" href="/profile/index.naver?u=vWlXGDBdOqyyM9ZZj5apMuUJWtcX5NndIARjqyYdUY0%3D">유성권</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420523645" rel="KIN">소액 민사채무관계ㅡ부동산취득관련</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('pearledmars')" href="/profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6CBqCVDPBff3XAaGxicyr3Y%3D">이종걸</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420503746" rel="KIN">민사소송 소장</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4240')" href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">김광웅</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420491262" rel="KIN">형사로 상대방 벌금 받았을 경우, 민사로 얼마나 청구할수 있나요?</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4240')" href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">김광웅</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420507908" rel="KIN">소액민사소송</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('kjkwon21')" href="/profile/index.naver?u=65Nch8PV7sL%2FGjMn0L8YNbF3QxITIE4cFZ%2BRRP7S1aI%3D">권광중</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420500704" rel="KIN">대여금반환소송 질문입니다</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('ahdrn001')" href="/profile/index.naver?u=cZ73OOnkHD4QIIuOjGk%2FUanSrJh3I4V6zRhQ9eMbS1Y%3D">이종윤</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.29.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420495509" rel="KIN">민사소송 패소이후</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('pearledmars')" href="/profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6CBqCVDPBff3XAaGxicyr3Y%3D">이종걸</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420492220" rel="KIN">민사재심소송</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('pangchul2')" href="/profile/index.naver?u=8MhFLnmXWeeiBbo22EK5mfn48mvd83Bc%2BdWKNHmKWn4%3D">김은철</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420484710" rel="KIN">물품값+대여금+외상값 합쳐서 대여금반환소송으로 통칭해서 소송했...</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4240')" href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">김광웅</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420251628" rel="KIN">컨설팅 사기를 당하였습니다 명품 중고거래 컨설팅을 해준다는 명...</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('tongkwon2')" href="/profile/index.naver?u=vWlXGDBdOqyyM9ZZj5apMuUJWtcX5NndIARjqyYdUY0%3D">유성권</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420481774" rel="KIN">물피도주 신고 및 민사소송</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4246')" href="/profile/index.naver?u=7aEm4AYuKBenQAT8pZDwykJ28Acl0yI%2BWTn%2FbbQMlr0%3D">이재호</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420454811" rel="KIN">민사소송 재산명시 채권자감치재판에 관하여</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4246')" href="/profile/index.naver?u=7aEm4AYuKBenQAT8pZDwykJ28Acl0yI%2BWTn%2FbbQMlr0%3D">이재호</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420437240" rel="KIN">민사소송 저는 피고이고 1심불참 서류를 못받았어요ㅠ 불복으로 항...</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('aabc4240')" href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">김광웅</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420352111" rel="KIN">소송사기 부디 고견부탁드립니다</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('partners4u')" href="/profile/index.naver?u=R0w%2B5jeNmZMeNKvnMWGnNeqHSidj0Jq%2Bm5jcZjZ5tP4%3D">최성민</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420464560" rel="KIN">허위사실 유포죄</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('partners4u')" href="/profile/index.naver?u=R0w%2B5jeNmZMeNKvnMWGnNeqHSidj0Jq%2Bm5jcZjZ5tP4%3D">최성민</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# <tr>
# <td class="title"><a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420455459" rel="KIN">민사소송에서  피고 아무게 에게 신청서 첨부 송달이 무슨뜻이고,...</a>
# </td>
# <td class="field"><a href="/qna/expertAnswerList.naver?dirId=60221">민사소송</a></td>
# <td class="questioner"><a class="_user_id _expert _param('ktkim1986')" href="/profile/index.naver?u=gMJEDYrGp5%2Fros%2Bp%2BV5B%2BQITc8IZLIcHAHXnjcHDuiI%3D">김경태</a></td> <!-- ID값은 변경하지 말아주세요 -->
# <td class="t_num">2022.05.28.</td>
# </tr>
# </tbody>
# </table>
# <ww:if test="false">
# </ww:if>
# <ww:else>
# </ww:else>
# <div class="paging space _tag_pager" style="display: none;">
# <div class="nav" style="display:block;"> <p class="btn"><a class="pr-prev _pre" href="#"><img alt="이전" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_prev.gif" title="이전" width="23"/></a><a class="pr-next _next" href="#"><img alt="다음" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_next.gif" title="다음" width="22"/></a></p></div>
# </div>
# <div class="paginate _default_pager">
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=1">1</a>
# <a class="on" href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=2" title="선택됨">2</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=3">3</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=4">4</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=5">5</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=6">6</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=7">7</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=8">8</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=9">9</a>
# <a href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=10">10</a>
# <a class="next" href="/qna/expertAnswerList.naver?dirId=60221&amp;queryTime=2022-05-31%2000%3A40%3A19&amp;page=11">다음페이지</a>
# </div>
# <div class="search">
# <form id="bottom_search" method="get" name="bottom_search">
# <input name="cs" type="hidden" value="utf8"/>
# <fieldset>
# <legend>검색영역</legend>
# <label class="blind" for="directoryId">디렉토리 분류 선택</label>
# <select id="directoryId" name="dirId">
# <option value="60201">교통 사고, 위반</option>
# <option value="60202">부동산, 건축</option>
# <option value="60203">신용, 파산</option>
# <option value="60204">가족, 이혼</option>
# <option value="60205">지식재산권</option>
# <option value="60206">형사사건</option>
# <option value="60207">소비자관련법, 상법</option>
# <option value="60208">청소년관련법</option>
# <option value="60209">@ 세금, 세무</option>
# <option value="60211">재판, 소송 절차</option>
# <option value="60212">계약</option>
# <option value="60213">손해배상</option>
# <option value="60214">형벌, 형집행</option>
# <option value="60215">법학, 법이론</option>
# <option value="60216">언론, 미디어 관련법</option>
# <option value="60217">외국법</option>
# <option value="60218">헌법</option>
# <option value="60219">행정법</option>
# <option value="60220">민법</option>
# <option selected="" value="60221">민사소송</option>
# <option value="60222">노동법</option>
# <option value="60223">등기</option>
# <option value="60224">민사집행</option>
# <option value="60225">산업재해</option>
# </select>
# <input accesskey="s" class="keyword" id="au_input_query" name="query" title="검색어" type="text"/>
# <input alt="검색" id="au_search_submit" src="https://ssl.pstatic.net/static/kin/09renewal/btn_search.gif" title="키워드 검색" type="image"/>
# </fieldset>
# </form>
# </div>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.QnaEnd.InputQuery.js" type="text/javascript"></script>
# </div>
# </div>
# <div class="btn_area_shortcut" id="bottom_area">
# <div class="section">
# <p>먼저 질문에 맞는 분야를 선택하고 질문을 작성하면,<br/>
# 				더 정확한 답변을 받을 수 있습니다.</p>
# <a class="button__type3 _clickcode:bbt.que btn" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver?dirId=60221&amp;d1Id=6', '?dirId=60221&amp;d1Id=6');" role="button">
# 			   질문하러 가기<i aria-hidden="true" class="sp_common ico_arrow_r"></i>
# </a>
# </div>
# <div class="section">
# <p>내 관심 분야, 관심키워드를 설정하면 답변할 수 있는<br/>
# 				질문을 바로 볼 수 있습니다.</p>
# <a class="button__type3 _ros _mng_dir _clickcode:bbt.fav" href="#" role="button">관심분야 설정<i class="sp_common ico_arrow_r"></i></a>
# </div>
# </div>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.QnaList.MyInterest.js" type="text/javascript"></script>
# </div>
# <div class="container-fluid-content__right">
# <div class="aside" id="au_aside">
# <script type="text/javascript">
# var rosAlertMessage = "";
# var isRosActionInterest = "false";
# </script>
# <div class="aside_myinfo" id="aside_login">
# <h2 class="blind">NAVER <em>로그인</em> 영역</h2>
# <div class="Ugc_login">
# <p class="top_text">활동소식이 궁금하다면,</p>
# <a class="login_button" href="https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fkin.naver.com%2Fqna%2FexpertAnswerList.naver%3FdirId%3D60221%26queryTime%3D2022-05-31%252000%253A40%253A19%26page%3D2">
# <span class="login_common UGC_login_text">NAVER <em>로그인</em></span>
# </a>
# <div class="sign_area">
# <div class="info_find">
# <a class="" href="https://nid.naver.com/user/help.nhn?todo=idinquiry" target="_blank">아이디 찾기</a>
# <span class="bar"></span>
# <a href="https://nid.naver.com/nidreminder.form" target="_blank">비밀번호 찾기</a>
# </div>
# <div class="sign_in">
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fkin.naver.com%2Fqna%2FexpertAnswerList.naver%3FdirId%3D60221%26queryTime%3D2022-05-31%252000%253A40%253A19%26page%3D2" target="_blank">회원가입</a>
# </div>
# </div>
# </div>
# <!-- 관심키워드 추가 레이어 -->
# <div class="layer_base layer_type1 _keywordLayer" style="width:277px; display:none;">
# <h1><label for="interestKeywordInput_login">관심키워드 설정</label></h1>
# <div class="find_keyword">
# <input class="input_txt _keywordInput" id="interestKeywordInput_login" maxlength="20" style="width:220px" type="text"/>
# <a class="_lookUpChildElement('img') _keywordAddBtn" href="#"><img alt="추가" class="_keywordAddBtn" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_add.gif" width="46"/></a>
# </div>
# <p class="_defaultMsg desc">관심 키워드는 20개까지 등록할 수 있습니다.</p>
# <p class="_overMsg desc" style="display:none"><em><strong>최대 키워드 개수(20개)를 초과하였습니다.</strong></em><br>기존에 등록한 관심키워드를 삭제하시면, 다시<br>다른 키워드를 추가하실 수 있습니다.</br></br></p>
# <p class="_errorMsg desc" style="display:none;"></p>
# <ul class="keyword _keywordList"></ul>
# <div class="btn">
# <a class="_lookUpChildElement('img') _closeLayer" href="#"><img alt="닫기" class="_closeLayer" height="28" src="https://ssl.pstatic.net/static/kin/09renewal/btn_close5.gif" width="48"/></a>
# </div>
# <a class="close2 _lookUpChildElement('img') _closeLayer _keywordLayerLastButton" href="#"><img alt="닫기" class="_closeLayer" height="19" src="https://ssl.pstatic.net/static/kin/09renewal/btn_close_layer3.gif" width="19"/></a>
# </div>
# <script id="errorMsgTpl" type="text/template">
# <em><strong>{=errorMsg}</strong></em>
# </script>
# <!-- //관심키워드 추가 레이어 -->
# </div>
# <!-- {{{ -->
# <script id="myKinGradeTpl" type="text/template">
# 	<div class="gradeup_info">
# 		<div class="lv_area grd_lv{=currentLevelOrder}">
# 			<div class="mylv">
# 				<div class="gauge" id="level_guage">
# 					<strong class="my_level">{=currentLevelName}</strong>
# 					<div class="grd_wrap">
#
# 						<div class="inner" style="width:0%;">
# 							<div class="grd_bar"><span class="grd_action"></span></div>
# 						</div>
# 					</div>
# 					<div class="my_level_num">
# 						내공: <strong>{=formattedTotalPoint}</strong>
# 					</div>
# 					<span class="my_level_up">{=nextLevelName}</span>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="nessesary_area">
# 			<ul class="nessesary_list">
# 				{if isMaxLevel}
# 				<li><p class="tit">내공</p><strong class="data">{=formattedTotalPoint}</strong></li>
# 				<li><p class="tit">채택답변수</p><strong class="data">{=formattedTotalBest}개</strong></li>
# 				<li><p class="tit">답변채택률</p><strong class="data">{=answerBestRate}%</strong></li>
# 				{else}
# 					{if nextLevelMinPoint - totalPoint <= 0}
# 					<li><p class="tit">내공</p><strong class="data">만족</strong></li>
# 					{else}
# 					<li><p class="tit">내공</p><strong class="data">{=formattedRemainPoint}필요</strong></li>
# 					{/if}
# 					{if nextLevelBestCnt - totalBest <= 0}
# 					<li><p class="tit">채택답변수</p><strong class="data">만족</strong></li>
# 					{else}
# 					<li><p class="tit">채택답변수</p><strong class="data">{=formattedRemainBestCnt}개 필요</strong></li>
# 					{/if}
# 					{if answerBestRate - nextLevelBestRate >= 0}
# 					<li><p class="tit">답변채택률</p><strong class="data">만족</strong></li>
# 					{else}
# 					<li><p class="tit">답변채택률</p><strong class="data">{=answerBestRate}%</strong></li>
# 					{/if}
# 				{/if}
# 			</ul>
# 		</div>
# 		{if isExpert}
# 		<a href="{=expertAnswerListUrl}" class="expert_answer">전문가 답변하기 <i>&gt;</i></a>
# 		{else}
# 		<ul class="major_area">
# 			<li><strong>활동분야</strong>
# 			{if activeDirList }{for num:activeDir in activeDirList}{if num!=0},{/if}{=activeDir.dirName}{/for}{else}활동 분야가 없습니다{/if}
# 			</li>
# 			<li><strong>내공순위</strong>{=formattedTotalPointRank}위</li>
# 			<li><strong>전체질문</strong>{=formattedTotalQuestion}건 (질문채택률 {=questionSelectRate}%)</li>
# 			<li><strong>전체답변</strong>{=formattedTotalAnswer}건</li>
# 		</ul>
# 		{/if}
# 	</div>
# </script>
# <script id="newQuestionDirTpl" type="text/template">
# 	<ul class="interest_menu">
# 		<li class="on"><a class="_clickcode:kmy_lgd.ndtab _subtab _param('0')" href="#">관심분야<span class="blind _selected">선택됨</span></a></li>
# 		<li><a class="_clickcode:kmy_lgd.nltab _subtab _param('1')" href="#">관심지역</a></li>
# 		<li><a class="_clickcode:kmy_lgd.nktab _subtab _param('2')" href="#">관심키워드</a></li>
# 	</ul>
# 	<h4 class="blind">나의 관심설정 중 관심분야</h4>
# {if bHasNewQuestion}
# 	<ul class="new_qna">
# 	{for num:q in newQuestions}
# 		<li class="list">
# 			<p class="q"><a href="{=q.detailUrl}" onClick="nhn.Kin.Utility.nClicks('kmy_lgd.ndq','{=q.dirId}_{=q.docId}','{=num+1}',event);">{=q.title }</a></p>
# 			<ul class="info">
# 			<li><a href="/qna/list.naver?dirId={=q.dirId }" onClick="nhn.Kin.Utility.nClicks('kmy_lgd.ndir', '{=q.dirId}', '{=num+1}', event);"><span class="ko">{=q.dirName }</span></a></li>
# 			<li>{=q.formattedWriteTime}</li>
# 			</ul>
# 		</li>
# 	{/for}
# 	</ul>
# {elseif bHasInterest}
# 	<div class="no_cont no_cont_v1">
# 		<strong>관심분야에 등록된 답변을 기다리는 질문이 없습니다.</strong>
# 	</div>
# 	<a href="#" class="expert_answer _clickcode:kmy_lgd.ndradd _ros _add_dir">관심분야 추가</a>
# {elseif bHasRecommend}
# 	<div class="no_cont">
# 		<strong>설정된 관심분야가 없습니다.</strong>
# 		<p>관심분야를 추가해보세요.</p>
# 		<div class="lst">
# 			<ul class="list_interest _interest_add">
# 			{for num:recommendDir in recommendDirs}
# 				<li>
# 					<div class="input_wrap">
# 						<input id="_interest{=num+1}" type="checkbox" class="chkbox _clickcode:kmy_lgd.ndrlist,i:{=recommendDir.dirId},r:{=num+1}" value="{=recommendDir.dirId }">
# 					</div>
# 					<label for="_interest{=num+1}">{=recommendDir.dirName}</label>
# 				</li>
# 			{/for}
# 			</ul>
# 		</div>
# 	</div>
# 	<a href="#" class="expert_answer _clickcode:kmy_lgd.ndradd _ros _add_dir">관심분야 추가</a>
# {else}
# 	<div class="no_cont no_cont_v1">
# 		<img src="https://ssl.pstatic.net/static/kin/09renewal/icon_exclamation.png" alt="알림이미지" width="24" height="24">
# 		<strong>설정된 관심분야가 없습니다.</strong>
# 		<p>관심분야를 추가해보세요.</p>
# 	</div>
# 	<a href="#" class="expert_answer _clickcode:kmy_lgd.ndradd _ros _add_dir">관심분야 추가</a>
# {/if}
# 	<a href="#" class="setting _ros _mng_dir _clickcode:kmy_lgd.ndset">관리</a>
# </script>
# <script id="newQuestionLocalTpl" type="text/template">
# 	<ul class="interest_menu">
# 		<li><a class="_clickcode:kmy_lgd.ndtab _subtab _param('0')" href="#">관심분야</a></li>
# 		<li class="on"><a class="_clickcode:kmy_lgd.nltab _subtab _param('1')" href="#">관심지역<span class="blind _selected">선택됨</span></a></li>
# 		<li><a class="_clickcode:kmy_lgd.nktab _subtab _param('2')" href="#">관심키워드</a></li>
# 	</ul>
# 	{if bHasNewQuestion}
# 	<ul class="new_qna">
# 		{for num:q in newQuestions}
# 		<li class="list">
# ...
# <dl>
# <dt><a href="/profile/index.naver?u=Omf58hn1iA7wRX00koEK2RxMSM8LjV7PhU61%2FOt%2BGBg%3D">국민신문고</a></dt>
# <dd class="cate">
# <a href="/qna/question.naver?dirId=601">민원, 행정</a>,
#
# 									<a href="/qna/question.naver?dirId=60105">국민신문고</a>
# </dd>
# </dl>
# </li>
# <li>
# <div class="thumb"><a href="/profile/index.naver?u=D6vwspK7vJp5mAXKCMia2NpiAb80QuRB%2FIJNMLtM6dM%3D" target="_blank"><img alt="지식파트너 프로필" height="60" src="https://kin-phinf.pstatic.net/20160908_154/1473268501402XCnQe_PNG/442.png" width="60"/><span class="bg_border"></span></a></div>
# <dl>
# <dt><a href="/profile/index.naver?u=D6vwspK7vJp5mAXKCMia2NpiAb80QuRB%2FIJNMLtM6dM%3D">국민건강보험공단...</a></dt>
# <dd class="cate">
# <a href="/qna/question.naver?dirId=6100401">국민건강보험</a>,
#
# 									<a href="/qna/question.naver?dirId=401030302">국민건강보험</a>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <!-- 지식카페 -->
# <div class="tc-panel">
# <ul class="directory_edit directory_edit_cafe">
# <li>
# <div class="thumb"><a href="https://cafe.naver.com/mylawyer" target="_blank"><img alt="지식카페 프로필" height="60" src="https://cafethumb.pstatic.net/20150311_203/afo1_1426042670413Y7m3M_JPEG/%BA%AF%C8%A3%BB%E72.jpg?type=r2" width="60"/><span class="bg_border"></span></a></div>
# <strong class="user"><a href="https://cafe.naver.com/mylawyer" target="_blank">우리변호사</a></strong>
# <dl class="detail">
# <dt>카페 답변</dt>
# <dd><em><strong>24,144</strong></em></dd>
# <dt>전문가 지수</dt>
# <dd><span class="num">0</span></dd>
# </dl>
# </li>
# <li>
# <div class="thumb"><a href="https://cafe.naver.com/wonderfulseniors" target="_blank"><img alt="지식카페 프로필" height="60" src="https://cafethumb.pstatic.net/MjAyMTA3MDhfMjIx/MDAxNjI1NzA4NzU4MTIx.X16vCaD9SdD80GDSXrkwdEMTzPMoXdfrBfDgaJ0tu60g.YEXbFdLses5XqcfgrLOdy_buhzA2AsG-1tHVcf2LmC4g.PNG/%25EB%2584%25A4%25EC%259D%25B4%25EB%25B2%2584%25EC%25B9%25B4%25ED%258E%2598%25EC%2595%2584%25EC%259D%25B4%25EC%25BD%259801.png?type=r2" width="60"/><span class="bg_border"></span></a></div>
# <strong class="user"><a href="https://cafe.naver.com/wonderfulseniors" target="_blank">원더풀 시니어 (중년, 노...</a></strong>
# <dl class="detail">
# <dt>카페 답변</dt>
# <dd><em><strong>98</strong></em></dd>
# <dt>전문가 지수</dt>
# <dd><span class="num">0</span></dd>
# </dl>
# </li>
# </ul>
# </div>
# </div>
# <span class="more"><a class="_moreUrl" href="/people/partner/index.naver">더보기</a></span>
# </div>
# <script type="text/javascript">
# 	new jindo.TabControl($("au_knowledge_tab")).attach({
# 		select : function (e) {
# 			var elTabs = this.getTabs();
# 			if ( elTabs && elTabs.length > 1 ) {
# 				var elMore = cssquery.getSingle("._moreUrl", this.getBaseElement());
# 				if (elMore){
# 					elMore.href = e.nIndex ? "/people/cafe/index.naver?dirId=6" : "/people/partner/index.naver";
# 				}
# 			}
# 		}
# 	});
# 	</script>
# <!-- 전문가 랭킹 -->
# <div class="aside_type1 _tab_expert_ranking_area">
# <h4 class="h_side_title type_default">
# <strong>민사소송</strong> 전문가 랭킹
# 		</h4>
# <ul class="aside_tab_module" role="tablist">
# <li class="tc-tab tc-selected"><a aria-selected="true" class="aside_tab_module__item is_active" href="#" onclick="return false;" role="tab"><span class="blind">전체 랭킹</span>전체 랭킹</a></li>
# <li class="tc-tab"><a aria-selected="false" class="aside_tab_module__item" href="#" onclick="return false;" role="tab"><span class="blind">급상승 랭킹</span>급상승 랭킹</a></li>
# </ul>
# <div class="panels">
# <ul class="aside_lank tc-panel tc-selected">
# <li class="first">
# <div class="lank num_top"><img alt="1" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU%2Fo%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20200206_9/1580966606954ikuRk_PNG/aaaa.png?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU/o=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*a.user,r:1" href="/profile/index.naver?u=nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU%2Fo%3D" title="Wind of warrior">
# <strong>Wind of warrior</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">
# <span class="if_t2">전문가지수</span>
# <span class="t_num">94151</span>
# </dd>
# </dl>
# </li>
# <li>
# <div class="lank num2"><img alt="2" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=lhEKQIiLepXLtFs%2FSyXA3slHLfCaeGsyl%2FhxB64MXdk%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20161130_42/1480509544056eY2Jv_JPEG/flying0480.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('lhEKQIiLepXLtFs/SyXA3slHLfCaeGsyl/hxB64MXdk=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*a.user,r:2" href="/profile/index.naver?u=lhEKQIiLepXLtFs%2FSyXA3slHLfCaeGsyl%2FhxB64MXdk%3D" title="모두다함께잘사는세상">
# <strong>모두다함께잘사는세상</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">
# <span class="if_t2">전문가지수</span>
# <span class="t_num">46483</span>
# </dd>
# </dl>
# </li>
# <li>
# <div class="lank num3"><img alt="3" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=LSd%2FlB3SDHjp24aEAaqVINFemFaHhQrT%2ByLY9bcpzG4%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20210806_147/1628234492963bI777_JPEG/1628234492673.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('LSd/lB3SDHjp24aEAaqVINFemFaHhQrT+yLY9bcpzG4=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*a.user,r:3" href="/profile/index.naver?u=LSd%2FlB3SDHjp24aEAaqVINFemFaHhQrT%2ByLY9bcpzG4%3D" title="가사소송닷컴">
# <strong>가사소송닷컴</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">
# <span class="if_t2">전문가지수</span>
# <span class="t_num">34934</span>
# </dd>
# </dl>
# </li>
# <li>
# <div class="lank num4"><img alt="4" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=e5kSHR4GIX1el0l5WleG%2B97ww%2B%2BG5O4VFKk7HWyBFQM%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20180517_148/1526538926562snTdv_JPEG/kyh.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('e5kSHR4GIX1el0l5WleG+97ww++G5O4VFKk7HWyBFQM=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*a.user,r:4" href="/profile/index.naver?u=e5kSHR4GIX1el0l5WleG%2B97ww%2B%2BG5O4VFKk7HWyBFQM%3D" title="김영화 법무사">
# <strong>김영화 법무사</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">
# <span class="if_t2">전문가지수</span>
# <span class="t_num">24706</span>
# </dd>
# </dl>
# </li>
# <li>
# <div class="lank num5"><img alt="5" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=ERj5gf1uWrt8RCRKcdSy8ag8Z6uCVXkp6UUFK4NEOC8%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20180324_191/1521821929818TAr00_JPEG/%C0%CF%C1%F6%B8%C5%C8%AD.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('ERj5gf1uWrt8RCRKcdSy8ag8Z6uCVXkp6UUFK4NEOC8=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*a.user,r:5" href="/profile/index.naver?u=ERj5gf1uWrt8RCRKcdSy8ag8Z6uCVXkp6UUFK4NEOC8%3D" title="일지매화">
# <strong>일지매화</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">
# <span class="if_t2">전문가지수</span>
# <span class="t_num">24699</span>
# </dd>
# </dl>
# </li>
# </ul>
# <ul class="aside_lank tc-panel">
# <li class="first">
# <div class="lank num_top"><img alt="1" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=bsW3kyCOZH23mdfOtQomY5qHswkjtTZGqeHZwQc2c5k%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20201108_83/1604784144346CvvpC_JPEG/%B3%AA%BB%F3%BC%F6_%BB%E7%C1%F82.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('bsW3kyCOZH23mdfOtQomY5qHswkjtTZGqeHZwQc2c5k=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*w.user,r:1" href="/profile/index.naver?u=bsW3kyCOZH23mdfOtQomY5qHswkjtTZGqeHZwQc2c5k%3D" title="나상수 손해사정사">
# <strong>나상수 손해사정사</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">전문가지수<span class="t_num">283</span></dd>
# </dl>
# </li>
# <li>
# <div class="lank num2"><img alt="2" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=LSd%2FlB3SDHjp24aEAaqVINFemFaHhQrT%2ByLY9bcpzG4%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20210806_147/1628234492963bI777_JPEG/1628234492673.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('LSd/lB3SDHjp24aEAaqVINFemFaHhQrT+yLY9bcpzG4=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*w.user,r:2" href="/profile/index.naver?u=LSd%2FlB3SDHjp24aEAaqVINFemFaHhQrT%2ByLY9bcpzG4%3D" title="가사소송닷컴">
# <strong>가사소송닷컴</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">전문가지수<span class="t_num">253</span></dd>
# </dl>
# </li>
# <li>
# <div class="lank num3"><img alt="3" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=wt8%2BWINpJRiFxr7LxLlWj3C2EApbXMg6JVE%2Fc5mAypE%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20140427_233/13985851494133LDVL_JPEG/new_022.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('wt8+WINpJRiFxr7LxLlWj3C2EApbXMg6JVE/c5mAypE=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*w.user,r:3" href="/profile/index.naver?u=wt8%2BWINpJRiFxr7LxLlWj3C2EApbXMg6JVE%2Fc5mAypE%3D">
# <strong>hanj****</strong> 님
#
# 									</a>
# </dd>
# <dd class="info">전문가지수<span class="t_num">193</span></dd>
# </dl>
# </li>
# <li>
# <div class="lank num4"><img alt="4" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU%2Fo%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20200206_9/1580966606954ikuRk_PNG/aaaa.png?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU/o=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*w.user,r:4" href="/profile/index.naver?u=nvfnobOEernylWOxPk3JN6djNpYhh7pzZXT1HlzyU%2Fo%3D" title="Wind of warrior">
# <strong>Wind of warrior</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">전문가지수<span class="t_num">182</span></dd>
# </dl>
# </li>
# <li>
# <div class="lank num5"><img alt="5" height="15" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="10"/></div>
# <dl>
# <dt class="thumb _photo_profile"><a href="/profile/index.naver?u=82DcJndBDFS6lUhkGWcMMcnrVfyUTDtYglQzhwlHkns%3D"><img alt="" height="33" src="https://kin-phinf.pstatic.net/20220306_154/1646538461961FurnB_JPEG/1517141985958.jpg?type=w33" width="33"/></a><a class="btn_play" href="#"><img alt="프로필 보기" class="_btn_profile _param('82DcJndBDFS6lUhkGWcMMcnrVfyUTDtYglQzhwlHkns=')" height="9" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="9"/></a></dt>
# <dd>
# <a class="_nclicks:rr2*w.user,r:5" href="/profile/index.naver?u=82DcJndBDFS6lUhkGWcMMcnrVfyUTDtYglQzhwlHkns%3D" title="법무사 차주민">
# <strong>법무사 차주민</strong> 님
#
#
# 									</a>
# </dd>
# <dd class="info">전문가지수<span class="t_num">151</span></dd>
# </dl>
# </li>
# </ul>
# </div>
# <span class="more _more"><a class="_nclicks:rr2.more" href="/qna/directoryExpertList.naver?dirId=60221">더보기</a></span>
# </div>
# <div class="_au_layer_profile_holder" style="position:absolute; top:0; left:33px;display:block">
# <div class="layer_base layer_profile _au_layer_profile" style="display:none;top:1px;">
# <p class="id"><a class="_profile_id" href="#">pear****</a> 중수 (847위)</p>
# <dl>
# <dt><strong>질문</strong> (마감률)</dt>
# <dd><strong>35</strong> (64.5%)</dd>
# <dt><strong>답변</strong> (채택률)</dt>
# <dd><strong>248</strong> (64.5%)</dd>
# </dl>
# <ul class="etc_link">
# <li><a href="#">프로필</a></li>
# </ul>
# <a class="close2" href="#"><img alt="닫기" class="_btn_profile_close" height="19" src="https://ssl.pstatic.net/static/kin/09renewal/btn_close_layer3.gif" width="19"/></a>
# </div>
# <iframe class="profile_layer_fix _au_iframe_profile" frameborder="0" scrolling="no" style="display:none;" title="내용없음"></iframe>
# </div>
# <script type="text/javascript">
# 		$Fn(function() {
# 			nhn.Kin.RNB.ExpertRankingArea.initialize(2);
# 		},this).attach(window,"load");
# 	</script>
# <div class="qna_lst_ban">
# <a href="/people/expert/joinExpert.naver" target="_blank"><img alt="지식iN 법률분야에서 전문지식을 나눠주실 변호사분들께 안내드립니다." height="89" src="https://ssl.pstatic.net/static/kin/09renewal/ban_qna_law.gif" width="280"/></a>
# </div>
# <div class="_au_layer_profile_holder" style="position:absolute; top:0; left:33px;display:block">
# <div class="layer_base layer_profile _au_layer_profile" style="display:none;top:1px;">
# <p class="id"><a class="_profile_id" href="#">pear****</a> 중수 (847위)</p>
# <dl>
# <dt><strong>질문</strong> (마감률)</dt>
# <dd><strong>35</strong> (64.5%)</dd>
# <dt><strong>답변</strong> (채택률)</dt>
# <dd><strong>248</strong> (64.5%)</dd>
# </dl>
# <ul class="etc_link">
# <li><a href="#">프로필</a></li>
# </ul>
# <a class="close2" href="#"><img alt="닫기" class="_btn_profile_close" height="19" src="https://ssl.pstatic.net/static/kin/09renewal/btn_close_layer3.gif" width="19"/></a>
# </div>
# <iframe class="profile_layer_fix _au_iframe_profile" frameborder="0" scrolling="no" style="display:none;" title="내용없음"></iframe>
# </div>
# <script type="text/javascript">
# 	nhn.Kin.Utility.initializeProfileBySPS($("aside_rightDirectory"));
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer_wrap">
# <div class="footer">
# <h2 class="blind">하위영역</h2>
# <div class="footer_menu">
# <a class="_nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.claim" href="http://inoti.naver.com/inoti/main.nhn" target="_blank">게시중단요청서비스</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.help" href="https://help.naver.com/support/service/main.nhn?serviceNo=1003" target="_blank">지식iN 고객센터</a>
# </div>
# <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.</p>
# </div>
# </div>
# <script type="text/javascript">
# 		lcs_do();
# 	</script>
# </div>
# </body>
# </html>

# %%
find_tbody = soup.find('tbody', id='au_board_list')
find_tbody.find_all('tr')[0].find('td', class_='questioner')
# Out:
# <td class="questioner"><a class="_user_id _expert _param('pearledmars')" href="/profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6CBqCVDPBff3XAaGxicyr3Y%3D">이종걸</a></td>

# %%
find_tbody.find_all('tr')[0].find('td', class_='questioner').text
# Out:
# '이종걸'

# %%
find_tbody.find_all('tr')[0].find('td', class_='questioner').find('a')['href']
# Out:
# '/profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6CBqCVDPBff3XAaGxicyr3Y%3D'

# %%
href_list = []
for page_num in tqdm(range(1, 100)):
    url = 'https://kin.naver.com/qna/expertAnswerList.naver?dirId=60221&queryTime=2022-05-31%2000%3A40%3A19&page=' + str(page_num)
    html = requests.get(url)
    soup = bs(html.text, 'html.parser')
    find_tbody = soup.find('tbody', id='au_board_list')
    for i in range(0, 20):
        name = find_tbody.find_all('tr')[i].find('td', class_='questioner').text
        href = find_tbody.find_all('tr')[i].find('td', class_='questioner').find('a')['href']
        href_list.append([name, href])
df = pd.DataFrame(href_list, columns=['변호사이름', '프로필링크'])
df
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
#      변호사이름                                              프로필링크
# 0      김광웅  /profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZ...
# 1      권광중  /profile/index.naver?u=65Nch8PV7sL%2FGjMn0L8YN...
# 2      이재호  /profile/index.naver?u=7aEm4AYuKBenQAT8pZDwykJ...
# 3      박준상  /profile/index.naver?u=cmhpqSOaub8JUQApVl9xd%2...
# 4      김낙의  /profile/index.naver?u=w4qHAUcPjjN42pElYiXJMss...
# ...    ...                                                ...
# 1975   이종걸  /profile/index.naver?u=YtCXOhk9ZHnFF%2BdQ1QbC6...
# 1976   이재호  /profile/index.naver?u=dEgr29uBZ5z0sTY%2FIic1U...
# 1977   권용덕  /profile/index.naver?u=MOGrF0CJ5LDhhtBxpVpWUpl...
# 1978   권용덕  /profile/index.naver?u=MOGrF0CJ5LDhhtBxpVpWUpl...
# 1979   김민기  /profile/index.naver?u=pkFg3jOGlqKsuj8xhjiynSw...
#
# [1980 rows x 2 columns]

# %%
df1 = df.copy()
df1['프로필링크'] = 'https://kin.naver.com/' + df1['프로필링크']
df1.head()
# Out:
#   변호사이름                                              프로필링크
# 0   김광웅  https://kin.naver.com//profile/index.naver?u=o...
# 1   권광중  https://kin.naver.com//profile/index.naver?u=6...
# 2   이재호  https://kin.naver.com//profile/index.naver?u=7...
# 3   박준상  https://kin.naver.com//profile/index.naver?u=c...
# 4   김낙의  https://kin.naver.com//profile/index.naver?u=w...

# %%
df1
# Out:
#      변호사이름                                              프로필링크
# 0      김광웅  https://kin.naver.com//profile/index.naver?u=o...
# 1      권광중  https://kin.naver.com//profile/index.naver?u=6...
# 2      이재호  https://kin.naver.com//profile/index.naver?u=7...
# 3      박준상  https://kin.naver.com//profile/index.naver?u=c...
# 4      김낙의  https://kin.naver.com//profile/index.naver?u=w...
# ...    ...                                                ...
# 1975   이종걸  https://kin.naver.com//profile/index.naver?u=Y...
# 1976   이재호  https://kin.naver.com//profile/index.naver?u=d...
# 1977   권용덕  https://kin.naver.com//profile/index.naver?u=M...
# 1978   권용덕  https://kin.naver.com//profile/index.naver?u=M...
# 1979   김민기  https://kin.naver.com//profile/index.naver?u=p...
#
# [1980 rows x 2 columns]

# %%
df1.drop_duplicates(subset=['변호사이름'], inplace = True)
df1
# Out:
#      변호사이름                                              프로필링크
# 0      김광웅  https://kin.naver.com//profile/index.naver?u=o...
# 1      권광중  https://kin.naver.com//profile/index.naver?u=6...
# 2      이재호  https://kin.naver.com//profile/index.naver?u=7...
# 3      박준상  https://kin.naver.com//profile/index.naver?u=c...
# 4      김낙의  https://kin.naver.com//profile/index.naver?u=w...
# ...    ...                                                ...
# 1736   박진세  https://kin.naver.com//profile/index.naver?u=d...
# 1858   권희영  https://kin.naver.com//profile/index.naver?u=e...
# 1886   안지성  https://kin.naver.com//profile/index.naver?u=i...
# 1906   김도훈  https://kin.naver.com//profile/index.naver?u=D...
# 1920   이도형  https://kin.naver.com//profile/index.naver?u=z...
#
# [77 rows x 2 columns]

# %%
df1.to_csv('민사변호사_프로필_링크', index=False)

# %% [markdown]
# 프로필 링크에서 남긴글로 들어가기

# %%
url = 'https://kin.naver.com/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D'

# %%
html = requests.get(url)
soup = bs(html.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="지식iN 전문가 프로필을 볼 수 있어요!" name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/profile.css" rel="stylesheet" type="text/css">
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="index,nofollow" name="robots">
# <meta content="장종현 변호사 프로필 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" property="og:url"/>
# <meta content="https://kin-phinf.pstatic.net/exphoto/expert/78/Vm5_1628126737850.jpg" property="og:image"/>
# <meta content="지식iN 전문가 프로필을 볼 수 있어요!" property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.2" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	장종현 변호사 프로필 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min';
#
# var g_ssc = ("kin.my" == "") ? "kin.temp" : "kin.my";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
# </script>
# </meta></meta></link></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_my" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#subMenuOfMykin" onclick="nhn.Kin.Utility.skipNavigation('subMenuOfMykin');return false;">하위 메뉴 바로가기</a>
# <a class="skip" href="#contentsOfMykin" onclick="nhn.Kin.Utility.skipNavigation('contentsOfMykin');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="logo_kin sp_common">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="sp_gnb icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);">지식iN</a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value=""/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_chat _chatButtonArea">
# <button aria-controls="chatMenu" aria-expanded="false" aria-haspopup="true" aria-pressed="false" class="button_chat" id="chatButton" type="button">
# <span class="blind">상담 목록</span>
# <span class="icon_chat"></span>
# <i class="icon_new" style="display: none"><span class="blind">NEW</span></i>
# </button>
# <div aria-hidden="true" class="chat_popup" id="chatMenu" role="menu">
# <a class="link_chat" href="/expert/center/counseling/list" role="menuitem" target="_blank">
# 								판매한 상품
# 								<i class="_counselorNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# <a class="link_chat" href="/counseling/purchases" role="menuitem" target="_blank">
# 								구매한 상품
# 								<i class="_counseleeNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# </div>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2022053101" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">전문가라면 엑스퍼트로 모십니다.</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner _containerFluidContentInner">
# <strong class="blind">현재 페이지 경로</strong>
# <ul class="location" id="au_location">
# <li><a href="/index.naver">홈</a></li>
# <li class="last">
# <a href="/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">
# 			행복로이어(k33k****)
#
#
# 			님의 프로필</a>
# </li>
# </ul>
# <!-- 프로모션 배너 -->
# <style type="text/css">
# .banner_kincommon {position:relative; float:right; width:190px; margin:-40px 0 0 0; z-index:23;}
# .banner_kincommon img {vertical-align:top;}
# </style>
# <!-- Personal_Info  -->
# <h2 class="blind">장종현님의 프로필</h2>
# <div class="my_lawyer">
# <div class="my_personal_top"></div>
# <div class="my_personal_inner">
# <div class="profile_section">
# <div class="profile_group">
# <a class="profile_animate profile_default" href="#">
# <span class="thumbnail">
# <img alt="장종현 님의 프로필" height="100%" src="https://kin-phinf.pstatic.net/exphoto/expert/78/Vm5_1628126737850.jpg" width="100%"/>
# </span>
# <span class="mask_bdr"></span>
# </a>
# </div>
# <div class="profile_info">
# <div class="profile_name">
# <strong class="profile_user">장종현</strong>
# </div>
# <span class="profile_like _hallEliteCheerBtnArea">
# <button class="profile_like_btn _hallEliteCheerBtn" data-u="ZOyoKXXwJit+zpbT6ISNHWmVYZw8C1dIyk/x9d0x6OQ=" onclick="nhn.Kin.Utility.nClicks('prf.like', '', '', event);">
# <i class="ico_profile_like">대단해요</i><em class="_cheerCnt">95</em>
# </button>
# </span>
# <div class="job">
# <strong>
#
# 						형사사건 변호사
# 					</strong>
# <span class="nt">(서울)</span>
# </div>
# <div class="profile_answer_date">변호사 답변 활동 <span>2012.01.~</span></div>
# </div>
# <div class="btn_info cert">
# <a class="btn_cert expert_question_button _nclicks:prf.lawyer" href="/qna/question.naver?expertType=lawyer">
# <i class="sp_common"></i>
# 						전문가에게 질문하기
# 					</a>
# </div>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Userinfo.EditorHistory.js" type="text/javascript"></script>
# </div>
# <div class="profile_section2">
# <div class="pro_intro">
# <dl class="pro_name">
# <dt>장종현</dt><dd><span class="p_lawyer">형사사건 변호사</span><span class="nt">(서울)</span></dd>
# </dl>
# <p class="position">법무법인 행복 구성원</p>
# <dl class="pro_info2">
# <dt>홈페이지</dt>
# <dd>
# <a href="http://cafe.daum.net/happylawer" target="_blank">http://cafe.daum.net/happylawer</a>
# <em class="bar">|</em>
# <a href="https://map.naver.com/v5/search/%EC%84%9C%EC%B4%88%EC%A4%91%EC%95%99%EB%A1%9C%20119/address/14139095.598767582,4507970.972918745,%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EC%84%9C%EC%B4%88%EA%B5%AC%20%EC%84%9C%EC%B4%88%EC%A4%91%EC%95%99%EB%A1%9C%20119,new?c=14139065.3309980,4507970.1451432,19,0,0,0,dh" target="_blank"><img alt="지도보기" height="18" src="https://ssl.pstatic.net/static/kin/09renewal/ico_map.gif" width="51"/></a>
# </dd>
# </dl>
# <p class="pro_desc">
# 					군형사, 일반 형사사건에 특화된 전문 변호사 02-534-2200
# 				</p>
# <div class="img_society"><a href="http://www.seoulbar.or.kr" target="_blank"><img alt="서울지방변호사회" height="29" src="https://kin-phinf.pstatic.net/storage/organization/organization_1259396007085.gif" width="100"/></a></div>
# </div>
# <div class="pro_main">
# <div class="hall_major">
# <div class="tit">
# <img alt="주요경력" height="11" src="/static/img/h_my_major.gif" width="39"/>
# </div>
# <ul class="_expert_rank_profile">
# <li>명예의 전당 2017.02. 채택왕 TOP 68위</li>
# </ul>
# </div>
# <dl>
# <dt>
#
# 					변호사답변 활동분야
#
#
#
#
#
#
#
#
#
# 				</dt>
# <dd><a href="/qna/list.naver?dirId=602">법, 법률</a></dd>
# </dl>
# </div>
# <div class="my_badge _param('ZOyoKXXwJit+zpbT6ISNHWmVYZw8C1dIyk/x9d0x6OQ=,1')">
# <ul>
# <li class="_badge">
# <a class="_badge_icon" href="#"><img alt="지식iN18주년배지" height="54" src="https://ssl.pstatic.net/static/common/blank.gif" style="background:url(https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t128.png?ver=20200914023854) no-repeat 0 0;_background:none;_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(src='https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t128.png?ver=20200914023854',sizingMethod='crop')" width="54"/></a>
# <div class="badge_bl">
# <div class="badge_bl_inner">
# <dl>
# <dt><strong>지식iN18주년배지</strong></dt>
# <dd>지식iN 18번째 생일을 함께 축하해주신 여러분께 드립니다!</dd>
# <dd class="date">배지 획득일 : <em>2020년 10월 7일</em></dd>
# </dl>
# </div>
# <a class="badge_bl_clse" href="#">닫기</a>
# </div>
# </li>
# <li class="_badge">
# <a class="_badge_icon" href="#"><img alt="분야별지식인 투표" height="54" src="https://ssl.pstatic.net/static/common/blank.gif" style="background:url(https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t124.png?ver=20190211052417) no-repeat 0 0;_background:none;_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(src='https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t124.png?ver=20190211052417',sizingMethod='crop')" width="54"/></a>
# <div class="badge_bl">
# <div class="badge_bl_inner">
# <dl>
# <dt><strong>분야별지식인 투표</strong></dt>
# <dd>2018 분야별 지식인 투표 인증!</dd>
# <dd class="date">배지 획득일 : <em>2019년 3월 6일</em></dd>
# </dl>
# </div>
# <a class="badge_bl_clse" href="#">닫기</a>
# </div>
# </li>
# <li class="_badge">
# <a class="_badge_icon" href="#"><img alt="지식iN16주년배지" height="54" src="https://ssl.pstatic.net/static/common/blank.gif" style="background:url(https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t122.png?ver=20180919041515) no-repeat 0 0;_background:none;_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(src='https://ssl.pstatic.net/static/kin/09renewal/promotion/badge/img_badge_t122.png?ver=20180919041515',sizingMethod='crop')" width="54"/></a>
# <div class="badge_bl">
# <div class="badge_bl_inner">
# <dl>
# <dt><strong>지식iN16주년배지</strong></dt>
# <dd>지식iN 16번째 생일을 함께 축하해주신 여러분들께 드립니다!</dd>
# <dd class="date">배지 획득일 : <em>2018년 10월 7일</em></dd>
# </dl>
# </div>
# <a class="badge_bl_clse" href="#">닫기</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="profile_section3" id="profile_section3">
# <dl class="answer_area grd_lv16">
# <dt>
#
# 				변호사답변
#
#
#
#
#
#
#
#
#
# 			</dt>
# <dd class="answer_num">14,657</dd>
# <dt>최근 1주간 답변</dt>
# <dd class="answer_num icon_level">
# <span class="weekly_num">9</span>
# <span class="lv_state"><em>은하신</em></span><a href="/people/levelup/index.naver" target="_blank"><img alt="등급안내" class="guide" height="21" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="21"/></a>
# </dd>
# </dl>
# <div class="career_area">
# <p><img alt="전문 분야 경력" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/h_career.gif" width="64"/></p>
# <ul class="career_list _career_list">
# <li>고등군사법원 고등판사</li>
# <li>국가인권위원회 현장인권센타 상담위원</li>
# <li>충남 계룡시 마을변호사</li>
# </ul>
# </div>
# <div class="career_area">
# <p><img alt="학력 및 자격면허" height="11" src="https://ssl.pstatic.net/static/kin/09renewal/h_license.gif" width="74"/></p>
# <ul class="career_list _career_list">
# <li>건국대학교 법과대학원 졸업</li>
# <li>제14회 군법무관임용고시 합격(변호사자격)</li>
# </ul>
# </div>
# <div class="helper_area">
# <div class="inner">
# <div class="icon_area">
# <i class="sp_common ico_helper"></i>
# </div>
# <div class="content_area">
# <em class="tit">도움을 준 사람 수 <a class="_helperLayerOpenBtn" href="#" onclick="nhn.Kin.Utility.nClicks('prf.helptip', '', '', event);"><img alt="도움말" height="16" src="https://ssl.pstatic.net/static/kin/09renewal/ico_help.png" width="16"/></a></em>
# <div class="layer_base layer_balloon" id="helperLayer" style="width:160px; top:15px; left:9px; display:none;">
# <p><em>장종현님</em>의 답변으로 도움을 받은 질문자 수 입니다.</p>
# <button class="close _lookUpChildElement('img') _helperLayerCloseBtn">
# <img alt="레이어팝업 닫기" src="https://ssl.pstatic.net/static/kin/09renewal/btn_close_layer.gif">
# </img></button>
# <div class="edge_center"></div>
# </div>
# <div class="count">
# <span class="num">13,688</span><span class="txt">명</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- {{{ -->
# <script id="tplBadgeList" type="text/template">
# 	{if acquiredBadgeList != null}
# 		{for badge in acquiredBadgeList}
# 		<li class="_badge">
# 			<a href="#"><img src="https://ssl.pstatic.net/static/common/blank.gif" width="54" height="54" alt="배지설명" style="background:url({=badge.badgeImageUrl}) no-repeat 0 0;_background:none;_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(src='{=badge.badgeImageUrl}',sizingMethod='crop')"></a>
# 			<div class="badge_bl {if badge.bingoId}extend{/if}">
# 			{if badge.bingoId}
# 				<div class="badge_bl_top"></div>
# 			{/if}
# 			<div class="badge_bl_inner">
# 				<dl>
# 				<dt><strong>{=badge.eventName}</strong></dt>
# 				<dd>{=badge.eventDesc}</dd>
# 				{if badge.acquireTimeMap}
# 					<dd class="date">배지 획득일 : <em>{=badge.acquireTimeMap.year}년 {=badge.acquireTimeMap.month}월 {=badge.acquireTimeMap.day}일</em></dd>
# 				{/if}
# 				{if badge.bingoId}
# 					<dd class="button"><a href="/bingo/bingoHome.naver?bingoId={=badge.bingoId}">빙고 바로가기</a></dd>
# 				{/if}
# 				</dl>
# 			</div>
# 			{if badge.bingoId}
# 				<div class="badge_bl_bottom"></div>
# 			{/if}
# 			<a href="#" class="badge_bl_clse">닫기</a>
# 		</li>
# 		{/for}
# 	{/if}
# </script>
# <!-- }}} -->
# <script type="text/javascript">
#
#
# var elNumbers = null;
# var elSpotDetail = $("profile_section3");
# if (elSpotDetail) {
# 	elNumbers = cssquery("._numberToImage", elSpotDetail);
# }
#
# if(elNumbers){
# 	for (var i = 0; i < elNumbers.length; i++) {
# 		aParam = nhn.Kin.Utility.extractParam(elNumbers[i].className);
# 		elNumbers[i].innerHTML = nhn.Kin.Utility.getTagNumberString(aParam[0], aParam[1]) + elNumbers[i].innerHTML;
# 	}
# }
# </script>
# <!--// Personal_Info  -->
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/naver.kin.ProfileAnimation.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Userinfo.MainProfileBox.js" type="text/javascript"></script>
# <a class="expert_banner" href="https://m.expert.naver.com/expert/profile/home?storeId=100004407">
# <img alt="expert" class="expert_logo" height="27" src="https://ssl.pstatic.net/static/kin/section/expert/pc/bannerLogoWhite.svg" width="78"/>
# <p class="title">
# <strong class="underline">행복로이어</strong>
# 			변호사 분야 엑스퍼트 활동중!</p>
# <div class="expert_btn">상담&amp;수업 전체보기</div>
# </a>
# <div class="container-fluid-content__left">
# <!--// Personal_Info  -->
# <div class="snb_wrap">
# <div class="snb snb_bordered snb_mykin">
# <h2 class="snb_title blind">프로필</h2>
# <ul class="snb_list">
# <li>
# <a href="/userinfo/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" id="subMenuOfMykin">답변 보기 <span class="num">(14,848)</span></a>
# <ul class="sub">
# <li><a href="/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">전문가 답변 <span class="num">(14,657)</span></a></li>
# </ul>
# </li>
# <li>
# <a href="/userinfo/opendicList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">오픈사전 보기 <span class="num">(0)</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container-fluid-content__right" id="content">
# <h4 class="h_my_title">
# <img alt="전문가 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/h_professional_answer.gif" width="68"/>
# <span class="eng">(14,657)</span>
# <span class="more"><a href="/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">더보기</a></span>
# </h4>
# <ul class="professional_answer">
# <li>
# <dl class="dlist_qna">
# <dt>
# <span class="ico_q"><img alt="질문" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420599326" id="contentsOfMykin">폭해을 당해 안와골절,왼쪽무릅쓸개골골절,이서증으로 상해진단을 받아 상대방을 고소...</a>
# <span class="date">2022.05.30.</span>
# </dt>
# <dd>
# <span class="ico_a"><img alt="답변" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.​민사소송에서 승소하여 채무자의 급여 내지 재산에 대하여 압...
# 			</dd>
# </dl>
# </li>
# <li>
# <dl class="dlist_qna">
# <dt>
# <span class="ico_q"><img alt="질문" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020604&amp;docId=420598487">재판끝난후</a>
# <span class="date">2022.05.30.</span>
# </dt>
# <dd>
# <span class="ico_a"><img alt="답변" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.​가해자를 상대로 배상명령이 내려졌다는 가해자의 급여 내지...
# 			</dd>
# </dl>
# </li>
# <li>
# <dl class="dlist_qna">
# <dt>
# <span class="ico_q"><img alt="질문" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420538223">병사 때 일로 전문하사가 되고서 처벌받을 수 있나요</a>
# <span class="date">2022.05.29.</span>
# </dt>
# <dd>
# <span class="ico_a"><img alt="답변" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.​도박죄에 대한 공소시효가 도과하지 않은 상태라면 병사시절...
# 			</dd>
# </dl>
# </li>
# <li>
# <dl class="dlist_qna">
# <dt>
# <span class="ico_q"><img alt="질문" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=420345976">상관모욕죄 적용 기준 관련 문의드립니다.</a>
# <span class="date">2022.05.26.</span>
# </dt>
# <dd>
# <span class="ico_a"><img alt="답변" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.​당시 주고받은 대화에 대한 녹음이 없는 상태에서 옆에 있던...
# 			</dd>
# </dl>
# </li>
# <li>
# <dl class="dlist_qna">
# <dt>
# <span class="ico_q"><img alt="질문" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420252402">군대 내 가혹행위</a>
# <span class="date">2022.05.25.</span>
# </dt>
# <dd>
# <span class="ico_a"><img alt="답변" height="14" src="https://ssl.pstatic.net/static/kin/09renewal/blank.gif" width="18"/></span>안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.​중대장인 지휘관에 의한 규정에 의한 얼차려가 아니라, 선임병...
# 			</dd>
# </dl>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="footer_wrap">
# <div class="footer">
# <h2 class="blind">하위영역</h2>
# <div class="footer_menu">
# <a class="_nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.claim" href="http://inoti.naver.com/inoti/main.nhn" target="_blank">게시중단요청서비스</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.help" href="https://help.naver.com/support/service/main.nhn?serviceNo=1003" target="_blank">지식iN 고객센터</a>
# </div>
# <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.</p>
# </div>
# </div>
# <script type="text/javascript">
# 		lcs_do();
# 	</script>
# </div>
# </body>
# </html>

# %%
ans_href = soup.find('div', class_='container-fluid-content__right').find('span', class_='more').find('a')['href']
ans_href
# Out:
# '/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D'

# %%
url2 = 'https://kin.naver.com/' + ans_href

# %%
url2
# Out:
# 'https://kin.naver.com//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D'

# %%
html = requests.get(url2)
soup = bs(html.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="지식iN에서 나의 활동을 한눈에 모아서 보세요!" name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/profile.css" rel="stylesheet" type="text/css">
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="k33k**** 님의 전문가 답변, 프로필 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="지식iN에서 나의 활동을 한눈에 모아서 보세요!" property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.2" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	k33k**** 님의 전문가 답변, 프로필 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min';
#
# var g_ssc = ("kin.my" == "") ? "kin.temp" : "kin.my";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
# </script>
# </meta></meta></link></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_my" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#subMenuOfMykin" onclick="nhn.Kin.Utility.skipNavigation('subMenuOfMykin');return false;">하위 메뉴 바로가기</a>
# <a class="skip" href="#contentsOfMykin" onclick="nhn.Kin.Utility.skipNavigation('contentsOfMykin');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="logo_kin sp_common">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="sp_gnb icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);">지식iN</a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value=""/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_chat _chatButtonArea">
# <button aria-controls="chatMenu" aria-expanded="false" aria-haspopup="true" aria-pressed="false" class="button_chat" id="chatButton" type="button">
# <span class="blind">상담 목록</span>
# <span class="icon_chat"></span>
# <i class="icon_new" style="display: none"><span class="blind">NEW</span></i>
# </button>
# <div aria-hidden="true" class="chat_popup" id="chatMenu" role="menu">
# <a class="link_chat" href="/expert/center/counseling/list" role="menuitem" target="_blank">
# 								판매한 상품
# 								<i class="_counselorNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# <a class="link_chat" href="/counseling/purchases" role="menuitem" target="_blank">
# 								구매한 상품
# 								<i class="_counseleeNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# </div>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2022053101" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">전문가라면 엑스퍼트로 모십니다.</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner _containerFluidContentInner">
# <strong class="blind">현재 페이지 경로</strong>
# <ul class="location" id="au_location">
# <li><a href="/index.naver">홈</a></li>
# <li>
# <a href="/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">
# 			행복로이어(k33k****)
#
#
# 			님의 프로필</a>
# </li>
# <li class="last">전문가 답변</li>
# </ul>
# <!-- 프로모션 배너 -->
# <style type="text/css">
# .banner_kincommon {position:relative; float:right; width:190px; margin:-40px 0 0 0; z-index:23;}
# .banner_kincommon img {vertical-align:top;}
# </style>
# <h2 class="blind">k33k****님의 프로필</h2>
# <!-- Personal_Info  -->
# <div class="my_lawyer">
# <div class="my_personal_top"></div>
# <div class="my_personal_inner my_personal_simple">
# <div class="profile_section">
# <div class="profile_info">
# <div class="profile_name">
# <a href="/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">
# <strong class="profile_user">장종현</strong>
# </a>
# </div>
# </div>
# <div class="btn_info cert">
# <a class="btn_cert expert_question_button _nclicks:prf.lawyer" href="/qna/question.naver?expertType=lawyer">
# <i class="sp_common"></i>
# 							전문가에게 질문하기
# 						</a>
# </div>
# </div>
# <div class="profile_section2">
# <div class="pro_intro">
# <dl class="pro_name">
# <dt>장종현</dt><dd><span class="p_lawyer">형사사건 변호사</span><span class="nt">(서울)</span></dd>
# </dl>
# <p class="position">법무법인 행복 구성원</p>
# </div>
# </div>
# <div class="profile_section3">
# <dl class="my_spec">
# <dt class="long">
#
# 					변호사
#
#
#
#
#
#
#
#
#
# 					답변
# 				</dt>
# <dd class="long"><strong>14,657</strong></dd>
# <dt class="long">최근 1주간 답변</dt>
# <dd class="long"><strong>9</strong></dd>
# <dt class="long">등급</dt>
# <dd class="long"><strong class="grade16">은하신</strong></dd> <!-- 등급에 따라 strong의 class가 변경됩니다. grade1~15 -->
# </dl>
# </div>
# </div>
# </div>
# <!--// Personal_Info  -->
# <!--// Personal_Info -->
# <div class="container-fluid-content__left">
# <!--// Personal_Info  -->
# <div class="snb_wrap">
# <div class="snb snb_bordered snb_mykin">
# <h2 class="snb_title blind">프로필</h2>
# <ul class="snb_list">
# <li class="is_active">
# <a href="/userinfo/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" id="subMenuOfMykin">답변 보기 <span class="num">(14,848)</span></a>
# <ul class="sub">
# <li class="is_active"><a href="/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">전문가 답변 <span class="num">(14,657)</span></a></li>
# </ul>
# </li>
# <li>
# <a href="/userinfo/opendicList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">오픈사전 보기 <span class="num">(0)</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container-fluid-content__right" id="content">
# <h3 class="blind">나의 답변 목록</h3>
# <dl class="mykin_num">
# <dt><img alt="전문가 답변 수" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro1.gif" width="71"/></dt>
# <dd>14657</dd>
# <dt><img alt="어제 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro2.gif" width="61"/></dt>
# <dd>3</dd>
# <dt><img alt="오늘 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro3.gif" width="61"/></dt>
# <dd>0</dd>
# <dt><img alt="전문가 답변 활동" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro4.gif" width="85"/></dt>
# <dd>2012.01.~</dd>
# </dl>
# <ul class="list1">
#
#
#
#
#
# </ul>
# <div class="sort_expert">
# <!-- [D] 활성화시 'on' -->
# <a class="on" href="/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">전체질문</a>
# </div>
# <table cellspacing="0" class="boardtype2 th_border" width="100%">
# <caption><span class="blind">전문가 답변 목록</span></caption>
# <colgroup>
# <col/>
# <col width="93"/>
# <col width="99"/>
# </colgroup>
# <thead>
# <tr>
# <th class="title" scope="col">제목</th>
# <th scope="col">디렉토리</th>
# <th class="title" scope="col">작성</th>
# </tr>
# <tr><td class="blank" colspan="3"></td></tr>
# </thead>
# <tbody id="au_board_list">
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420599326" rel="KIN">폭해을 당해 안와골절,왼쪽무릅쓸개골골절,...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020604&amp;docId=420598487" rel="KIN">재판끝난후</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020604">재산범죄</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420538223" rel="KIN">병사 때 일로 전문하사가 되고서 처벌받을...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=420345976" rel="KIN">상관모욕죄 적용 기준 관련 문의드립니다.</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60211">재판, 소송 절차</a></td>
# <td class="t_num tc">2022.05.27.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420252402" rel="KIN">군대 내 가혹행위</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.25.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=420185784" rel="KIN">폭행죄 고소</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.05.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=420188081" rel="KIN">폭행사건 민사소송</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.05.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020603&amp;docId=420082144" rel="KIN">군대에서 대상관 범죄? 대상관 모욕죄??를...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020603">경범죄</a></td>
# <td class="t_num tc">2022.05.23.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=418553623" rel="KIN">형사조정위원회에서는 무슨 얘기를 하나요?</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.02.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=418488272" rel="KIN">동반입대 질문드립니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.05.02.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=418422449" rel="KIN">사기죄 형사재판</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60211">재판, 소송 절차</a></td>
# <td class="t_num tc">2022.04.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060402&amp;docId=417947963" rel="KIN">사기죄고소후 구약식</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060402">사기</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417947073" rel="KIN">폭행관련 합의시</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=417904406" rel="KIN">명예훼손 고소 가능한가요?</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060402&amp;docId=417889627" rel="KIN">중고나라 사기 기소유예</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060402">사기</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020602&amp;docId=417832223" rel="KIN">술마시고 친구에게 일방적으로 맞았습니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020602">강력범죄</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=417846058" rel="KIN">돈을 빌려줬습니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=417921294" rel="KIN">준비서면 제출시 입증서류 문의</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417944477" rel="KIN">폭행 민사소송 멱</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417879624" rel="KIN">쌍방폭행진단서제출해야하나요한쪽에서만제...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.23.</td>
# </tr>
# </tbody>
# </table>
# <ww:if test="false">
# </ww:if>
# <ww:else>
# </ww:else>
# <div class="paging space _tag_pager" style="display: none;">
# <div class="nav" style="display:block;"> <p class="btn"><a class="pr-prev _pre" href="#"><img alt="이전" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_prev.gif" title="이전" width="23"/></a><a class="pr-next _next" href="#"><img alt="다음" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_next.gif" title="다음" width="22"/></a></p></div>
# </div>
# <div class="paginate _default_pager">
# <a class="on" href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=1" title="선택됨">1</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=2">2</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=3">3</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=4">4</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=5">5</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=6">6</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=7">7</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=8">8</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=9">9</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=10">10</a>
# <a class="next" href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=11">다음페이지</a>
# </div>
# <div class="search">
# <form action="/userinfo/expert/answerList.naver" id="frmSearch" method="get" name="frmSearch">
# <fieldset>
# <legend>검색영역</legend>
# <input name="u" type="hidden" value="ZOyoKXXwJit+zpbT6ISNHWmVYZw8C1dIyk/x9d0x6OQ="/>
# <input accesskey="s" class="keyword" id="au_search_bar" maxlength="200" name="query" title="검색어" type="text" value="키워드를 입력해주세요."/>
# <input alt="검색" src="https://ssl.pstatic.net/static/kin/09renewal/btn_search.gif" title="키워드 검색" type="image"/>
# </fieldset>
# </form>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_ing" style="width:291px; top:392px; _top:394px; right:84px; display:none;">
# <h2 class="blind">승인 중</h2>
# <p>혹시나 있을 홍보성 답변이나 법적인 문제가 있을 수 있는<br/>단어 및 오탈자를 검토하는 과정으로 소속되어 있는 협회 및<br/>단체에서 직접 검토하여 서비스에 신중하게 노출하기 위한 <br/>과정입니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_complete" style="width:287px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">수정 후 반영</h2>
# <p>일부 수정 후 반영된 경우에, 답변 목록에서 해당 답변에<br/>이와 같이 표시되며 클릭하면 운영자 메시지를 확인하실 수 <br/>있습니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_hold" style="width:250px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">승인보류</h2>
# <p>해당 답변이 운영자에 의해 승인 보류된 상태로,<br/>클릭하면 운영자 메시지를 확인하실 수 있습니다.<br/>단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <script type="text/javascript">
# 		function expertThankLayerdisplay(el){
# 			var _layer = cssquery.getSingle('.layer_wrap',el);
#
# 			if( _layer.style.display =='block' )
# 				_layer.style.display ='none';
# 			else
# 				_layer.style.display ='block';
# 		}
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Myinfo.ExpertAnswerList.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Userinfo.SearchBar.js" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="footer_wrap">
# <div class="footer">
# <h2 class="blind">하위영역</h2>
# <div class="footer_menu">
# <a class="_nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.claim" href="http://inoti.naver.com/inoti/main.nhn" target="_blank">게시중단요청서비스</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.help" href="https://help.naver.com/support/service/main.nhn?serviceNo=1003" target="_blank">지식iN 고객센터</a>
# </div>
# <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.</p>
# </div>
# </div>
# <script type="text/javascript">
# 		lcs_do();
# 	</script>
# </div>
# </body>
# </html>

# %%
cotent_soup = soup.find('div', class_='container-fluid-content__right')
cotent_soup
# Out:
# <div class="container-fluid-content__right" id="content">
# <h3 class="blind">나의 답변 목록</h3>
# <dl class="mykin_num">
# <dt><img alt="전문가 답변 수" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro1.gif" width="71"/></dt>
# <dd>14657</dd>
# <dt><img alt="어제 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro2.gif" width="61"/></dt>
# <dd>3</dd>
# <dt><img alt="오늘 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro3.gif" width="61"/></dt>
# <dd>0</dd>
# <dt><img alt="전문가 답변 활동" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro4.gif" width="85"/></dt>
# <dd>2012.01.~</dd>
# </dl>
# <ul class="list1">
#
#
#
#
#
# </ul>
# <div class="sort_expert">
# <!-- [D] 활성화시 'on' -->
# <a class="on" href="/userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D">전체질문</a>
# </div>
# <table cellspacing="0" class="boardtype2 th_border" width="100%">
# <caption><span class="blind">전문가 답변 목록</span></caption>
# <colgroup>
# <col/>
# <col width="93"/>
# <col width="99"/>
# </colgroup>
# <thead>
# <tr>
# <th class="title" scope="col">제목</th>
# <th scope="col">디렉토리</th>
# <th class="title" scope="col">작성</th>
# </tr>
# <tr><td class="blank" colspan="3"></td></tr>
# </thead>
# <tbody id="au_board_list">
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=420599326" rel="KIN">폭해을 당해 안와골절,왼쪽무릅쓸개골골절,...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020604&amp;docId=420598487" rel="KIN">재판끝난후</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020604">재산범죄</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420538223" rel="KIN">병사 때 일로 전문하사가 되고서 처벌받을...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=420345976" rel="KIN">상관모욕죄 적용 기준 관련 문의드립니다.</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60211">재판, 소송 절차</a></td>
# <td class="t_num tc">2022.05.27.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=420252402" rel="KIN">군대 내 가혹행위</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.25.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=420185784" rel="KIN">폭행죄 고소</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.05.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=420188081" rel="KIN">폭행사건 민사소송</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.05.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020603&amp;docId=420082144" rel="KIN">군대에서 대상관 범죄? 대상관 모욕죄??를...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020603">경범죄</a></td>
# <td class="t_num tc">2022.05.23.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=418553623" rel="KIN">형사조정위원회에서는 무슨 얘기를 하나요?</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.05.02.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=418488272" rel="KIN">동반입대 질문드립니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.05.02.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60211&amp;docId=418422449" rel="KIN">사기죄 형사재판</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60211">재판, 소송 절차</a></td>
# <td class="t_num tc">2022.04.30.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060402&amp;docId=417947963" rel="KIN">사기죄고소후 구약식</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060402">사기</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417947073" rel="KIN">폭행관련 합의시</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=417904406" rel="KIN">명예훼손 고소 가능한가요?</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060402&amp;docId=417889627" rel="KIN">중고나라 사기 기소유예</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060402">사기</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=6020602&amp;docId=417832223" rel="KIN">술마시고 친구에게 일방적으로 맞았습니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=6020602">강력범죄</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=417846058" rel="KIN">돈을 빌려줬습니다</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=60221&amp;docId=417921294" rel="KIN">준비서면 제출시 입증서류 문의</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=60221">민사소송</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417944477" rel="KIN">폭행 민사소송 멱</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.24.</td>
# </tr>
# <tr>
# <td class="title">
# <a href="/qna/detail.naver?d1id=6&amp;dirId=602060203&amp;docId=417879624" rel="KIN">쌍방폭행진단서제출해야하나요한쪽에서만제...</a>
# </td>
# <td class="field"><a href="/qna/list.naver?dirId=602060203">폭행</a></td>
# <td class="t_num tc">2022.04.23.</td>
# </tr>
# </tbody>
# </table>
# <ww:if test="false">
# </ww:if>
# <ww:else>
# </ww:else>
# <div class="paging space _tag_pager" style="display: none;">
# <div class="nav" style="display:block;"> <p class="btn"><a class="pr-prev _pre" href="#"><img alt="이전" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_prev.gif" title="이전" width="23"/></a><a class="pr-next _next" href="#"><img alt="다음" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_next.gif" title="다음" width="22"/></a></p></div>
# </div>
# <div class="paginate _default_pager">
# <a class="on" href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=1" title="선택됨">1</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=2">2</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=3">3</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=4">4</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=5">5</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=6">6</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=7">7</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=8">8</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=9">9</a>
# <a href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=10">10</a>
# <a class="next" href="//userinfo/expert/answerList.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D&amp;page=11">다음페이지</a>
# </div>
# <div class="search">
# <form action="/userinfo/expert/answerList.naver" id="frmSearch" method="get" name="frmSearch">
# <fieldset>
# <legend>검색영역</legend>
# <input name="u" type="hidden" value="ZOyoKXXwJit+zpbT6ISNHWmVYZw8C1dIyk/x9d0x6OQ="/>
# <input accesskey="s" class="keyword" id="au_search_bar" maxlength="200" name="query" title="검색어" type="text" value="키워드를 입력해주세요."/>
# <input alt="검색" src="https://ssl.pstatic.net/static/kin/09renewal/btn_search.gif" title="키워드 검색" type="image"/>
# </fieldset>
# </form>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_ing" style="width:291px; top:392px; _top:394px; right:84px; display:none;">
# <h2 class="blind">승인 중</h2>
# <p>혹시나 있을 홍보성 답변이나 법적인 문제가 있을 수 있는<br/>단어 및 오탈자를 검토하는 과정으로 소속되어 있는 협회 및<br/>단체에서 직접 검토하여 서비스에 신중하게 노출하기 위한 <br/>과정입니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_complete" style="width:287px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">수정 후 반영</h2>
# <p>일부 수정 후 반영된 경우에, 답변 목록에서 해당 답변에<br/>이와 같이 표시되며 클릭하면 운영자 메시지를 확인하실 수 <br/>있습니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_hold" style="width:250px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">승인보류</h2>
# <p>해당 답변이 운영자에 의해 승인 보류된 상태로,<br/>클릭하면 운영자 메시지를 확인하실 수 있습니다.<br/>단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <script type="text/javascript">
# 		function expertThankLayerdisplay(el){
# 			var _layer = cssquery.getSingle('.layer_wrap',el);
#
# 			if( _layer.style.display =='block' )
# 				_layer.style.display ='none';
# 			else
# 				_layer.style.display ='block';
# 		}
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Myinfo.ExpertAnswerList.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Userinfo.SearchBar.js" type="text/javascript"></script>
# </div>

# %%
cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[0].find('td', class_='field').find('a').text
# Out:
# '민사소송'

# %%
cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[0].find('td', class_='title').text
# Out:
# '\n폭해을 당해 안와골절,왼쪽무릅쓸개골골절,...\n'

# %%
cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[0].find('td', class_='title').find('a')['href']
# Out:
# '/qna/detail.naver?d1id=6&dirId=60221&docId=420599326'

# %%
int(soup.find('div', class_ =  'container-fluid-content__left').find_all('span', class_='num')[1].text[1:-1].replace(',', '') ) // 20
# Out:
# 732

# %%
url3 = 'https://kin.naver.com/' + cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[0].find('td', class_='title').find('a')['href']
url3
# Out:
# 'https://kin.naver.com//qna/detail.naver?d1id=6&dirId=60221&docId=420599326'

# %%
html = requests.get(url3)
soup = bs(html.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="지식iN에서 나의 활동을 한눈에 모아서 보세요!" name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/css/min/profile.css" rel="stylesheet" type="text/css">
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="noindex,nofollow" name="robots">
# <meta content="aabc**** 님의 전문가 답변, 프로필 : 네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="지식iN에서 나의 활동을 한눈에 모아서 보세요!" property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.2" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	aabc**** 님의 전문가 답변, 프로필 : 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min';
#
# var g_ssc = ("kin.my" == "") ? "kin.temp" : "kin.my";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
# </script>
# </meta></meta></link></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_my" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#subMenuOfMykin" onclick="nhn.Kin.Utility.skipNavigation('subMenuOfMykin');return false;">하위 메뉴 바로가기</a>
# <a class="skip" href="#contentsOfMykin" onclick="nhn.Kin.Utility.skipNavigation('contentsOfMykin');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="logo_kin sp_common">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="sp_gnb icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);">지식iN</a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value=""/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_chat _chatButtonArea">
# <button aria-controls="chatMenu" aria-expanded="false" aria-haspopup="true" aria-pressed="false" class="button_chat" id="chatButton" type="button">
# <span class="blind">상담 목록</span>
# <span class="icon_chat"></span>
# <i class="icon_new" style="display: none"><span class="blind">NEW</span></i>
# </button>
# <div aria-hidden="true" class="chat_popup" id="chatMenu" role="menu">
# <a class="link_chat" href="/expert/center/counseling/list" role="menuitem" target="_blank">
# 								판매한 상품
# 								<i class="_counselorNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# <a class="link_chat" href="/counseling/purchases" role="menuitem" target="_blank">
# 								구매한 상품
# 								<i class="_counseleeNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# </div>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2022053102" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">전문가라면 엑스퍼트로 모십니다.</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner _containerFluidContentInner">
# <strong class="blind">현재 페이지 경로</strong>
# <ul class="location" id="au_location">
# <li><a href="/index.naver">홈</a></li>
# <li>
# <a href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">
# 			김광웅변호사(aabc****)
#
#
# 			님의 프로필</a>
# </li>
# <li class="last">전문가 답변</li>
# </ul>
# <!-- 프로모션 배너 -->
# <style type="text/css">
# .banner_kincommon {position:relative; float:right; width:190px; margin:-40px 0 0 0; z-index:23;}
# .banner_kincommon img {vertical-align:top;}
# </style>
# <h2 class="blind">aabc****님의 프로필</h2>
# <!-- Personal_Info  -->
# <div class="my_lawyer">
# <div class="my_personal_top"></div>
# <div class="my_personal_inner my_personal_simple">
# <div class="profile_section">
# <div class="profile_info">
# <div class="profile_name">
# <a href="/profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">
# <strong class="profile_user">김광웅</strong>
# </a>
# </div>
# </div>
# <div class="btn_info cert">
# <a class="btn_cert expert_question_button _nclicks:prf.lawyer" href="/qna/question.naver?expertType=lawyer">
# <i class="sp_common"></i>
# 							전문가에게 질문하기
# 						</a>
# </div>
# </div>
# <div class="profile_section2">
# <div class="pro_intro">
# <dl class="pro_name">
# <dt>김광웅</dt><dd><span class="p_lawyer"> 변호사</span><span class="nt">(경기)</span></dd>
# </dl>
# <p class="position">법률사무소 율민 변호사</p>
# </div>
# </div>
# <div class="profile_section3">
# <dl class="my_spec">
# <dt class="long">
#
# 					변호사
#
#
#
#
#
#
#
#
#
# 					답변
# 				</dt>
# <dd class="long"><strong>2,621</strong></dd>
# <dt class="long">최근 1주간 답변</dt>
# <dd class="long"><strong>32</strong></dd>
# <dt class="long">등급</dt>
# <dd class="long"><strong class="grade13">달신</strong></dd> <!-- 등급에 따라 strong의 class가 변경됩니다. grade1~15 -->
# </dl>
# </div>
# </div>
# </div>
# <!--// Personal_Info  -->
# <!--// Personal_Info -->
# <div class="container-fluid-content__left">
# <!--// Personal_Info  -->
# <div class="snb_wrap">
# <div class="snb snb_bordered snb_mykin">
# <h2 class="snb_title blind">프로필</h2>
# <ul class="snb_list">
# <li class="is_active">
# <a href="/userinfo/answerList.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D" id="subMenuOfMykin">답변 보기 <span class="num">(2,621)</span></a>
# <ul class="sub">
# <li class="is_active"><a href="/userinfo/expert/answerList.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">전문가 답변 <span class="num">(2,621)</span></a></li>
# </ul>
# </li>
# <li>
# <a href="/userinfo/opendicList.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">오픈사전 보기 <span class="num">(0)</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container-fluid-content__right" id="content">
# <h3 class="blind">나의 답변 목록</h3>
# <dl class="mykin_num">
# <dt><img alt="전문가 답변 수" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro1.gif" width="71"/></dt>
# <dd>2621</dd>
# <dt><img alt="어제 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro2.gif" width="61"/></dt>
# <dd>6</dd>
# <dt><img alt="오늘 한 답변" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro3.gif" width="61"/></dt>
# <dd>0</dd>
# <dt><img alt="전문가 답변 활동" height="13" src="https://ssl.pstatic.net/static/kin/09renewal/tx_kin_pro4.gif" width="85"/></dt>
# <dd>2020.12.~</dd>
# </dl>
# <ul class="list1">
#
#
#
#
#
# </ul>
# <div class="sort_expert">
# <!-- [D] 활성화시 'on' -->
# <a class="on" href="/userinfo/expert/answerList.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D">전체질문</a>
# </div>
# <table cellspacing="0" class="boardtype2 th_border" width="100%">
# <caption><span class="blind">전문가 답변 목록</span></caption>
# <colgroup>
# <col/>
# <col width="93"/>
# <col width="99"/>
# </colgroup>
# <thead>
# <tr>
# <th class="title" scope="col">제목</th>
# <th scope="col">디렉토리</th>
# <th class="title" scope="col">작성</th>
# </tr>
# <tr><td class="blank" colspan="3"></td></tr>
# </thead>
# <tbody id="au_board_list">
# <tr><td class="result_no" colspan="3">등록된 게시물이 없습니다.</td> </tr>
# </tbody>
# </table>
# <ww:if test="false">
# </ww:if>
# <ww:else>
# </ww:else>
# <div class="paging space _tag_pager" style="display: none;">
# <div class="nav" style="display:block;"> <p class="btn"><a class="pr-prev _pre" href="#"><img alt="이전" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_prev.gif" title="이전" width="23"/></a><a class="pr-next _next" href="#"><img alt="다음" height="23" src="https://ssl.pstatic.net/static/kin/09renewal/btn_nav3_next.gif" title="다음" width="22"/></a></p></div>
# </div>
# <div class="paginate _default_pager">
# </div>
# <div class="search">
# <form action="/userinfo/expert/answerList.naver" id="frmSearch" method="get" name="frmSearch">
# <fieldset>
# <legend>검색영역</legend>
# <input name="u" type="hidden" value="o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB+wLm3h8jQ="/>
# <input accesskey="s" class="keyword" id="au_search_bar" maxlength="200" name="query" title="검색어" type="text" value="키워드를 입력해주세요."/>
# <input alt="검색" src="https://ssl.pstatic.net/static/kin/09renewal/btn_search.gif" title="키워드 검색" type="image"/>
# </fieldset>
# </form>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_ing" style="width:291px; top:392px; _top:394px; right:84px; display:none;">
# <h2 class="blind">승인 중</h2>
# <p>혹시나 있을 홍보성 답변이나 법적인 문제가 있을 수 있는<br/>단어 및 오탈자를 검토하는 과정으로 소속되어 있는 협회 및<br/>단체에서 직접 검토하여 서비스에 신중하게 노출하기 위한 <br/>과정입니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_complete" style="width:287px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">수정 후 반영</h2>
# <p>일부 수정 후 반영된 경우에, 답변 목록에서 해당 답변에<br/>이와 같이 표시되며 클릭하면 운영자 메시지를 확인하실 수 <br/>있습니다. 단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <div class="layer_base layer_balloon" id="help_pro_hold" style="width:250px; top:392px; _top:394px; right:1px; display:none;">
# <h2 class="blind">승인보류</h2>
# <p>해당 답변이 운영자에 의해 승인 보류된 상태로,<br/>클릭하면 운영자 메시지를 확인하실 수 있습니다.<br/>단, 이 표시는 본인만 보실 수 있습니다.</p>
# <div class="edge_right"></div>
# </div>
# <script type="text/javascript">
# 		function expertThankLayerdisplay(el){
# 			var _layer = cssquery.getSingle('.layer_wrap',el);
#
# 			if( _layer.style.display =='block' )
# 				_layer.style.display ='none';
# 			else
# 				_layer.style.display ='block';
# 		}
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Myinfo.ExpertAnswerList.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20220511141354/js/min/nhn.Kin.Userinfo.SearchBar.js" type="text/javascript"></script>
# </div>
# </div>
# </div>
# </div>
# <div class="footer_wrap">
# <div class="footer">
# <h2 class="blind">하위영역</h2>
# <div class="footer_menu">
# <a class="_nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.claim" href="http://inoti.naver.com/inoti/main.nhn" target="_blank">게시중단요청서비스</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.help" href="https://help.naver.com/support/service/main.nhn?serviceNo=1003" target="_blank">지식iN 고객센터</a>
# </div>
# <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.</p>
# </div>
# </div>
# <script type="text/javascript">
# 		lcs_do();
# 	</script>
# </div>
# </body>
# </html>

# %%
soup.find('div', class_='title').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18124\1976866328.py in <cell line: 1>()
# ----> 1 soup.find('div', class_='title').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
soup.find('div', class_='c-heading__content').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18124\3500729336.py in <cell line: 1>()
# ----> 1 soup.find('div', class_='c-heading__content').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
ans_list =soup.find_all('div', class_='answer-content__list _answerList')
ans_list
# Out:
# [<div class="answer-content__list _answerList">
#  <div class="answer-content__item _contentWrap _answer" id="answer_1">
#  <a href="#answer1" name="answer1"><span class="blind">1번째 답변</span></a>
#  <div class="c-heading-answer">
#  <div class="c-heading-answer__profile">
#  <div class="profile-default">
#  <a class="profile-default--inner" href="/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" onclick="naver.kin.pc.common.nClicks('end*a.profile', '', '', event);" target="_blank">
#  <span class="profile-default__thumbnail" style="background-image: url('https://kin-phinf.pstatic.net/exphoto/expert/78/Vm5_1628126737850_small.jpg');"><span class="blind">장종현 님 프로필 이미지</span></span>
#  </a>
#  </div>
#  </div>
#  <div class="c-heading-answer__body">
#  <div class="c-heading-answer__title">
#  <p class="title">
#  <a class="badgeExpert" href="https://m.expert.naver.com" onclick="naver.kin.pc.common.nClicks('end*a.expert', '', '', event);" target="_blank">
#  <span class="blind">eXpert</span>
#  <svg fill="#FFF" height="16" viewbox="0 0 45 16" width="45" xmlns="http://www.w3.org/2000/svg">
#  <rect fill="#7E96FF" height="16" rx="8" width="45"></rect>
#  <path d="M13.957 8.07l-2.001-2.577a.09.09 0 0 1-.008-.097.1.1 0 0 1 .088-.051h.866c.078 0 .152.034.198.093l1.45 1.87 3.272-4.215A.252.252 0 0 1 18.019 3h.866a.1.1 0 0 1 .088.051.09.09 0 0 1-.008.098L15.142 8.07l2.003 2.577a.09.09 0 0 1 .01.098.1.1 0 0 1-.09.051h-.87a.254.254 0 0 1-.197-.093l-1.45-1.87-1.449 1.87a.252.252 0 0 1-.198.093h-.865a.1.1 0 0 1-.09-.051.09.09 0 0 1 .01-.098l2-2.577zM8.94 10.92c-.856 0-1.56-.268-2.11-.802C6.28 9.582 6.003 8.9 6 8.07c0-.814.273-1.492.818-2.034a2.792 2.792 0 0 1 2.047-.815 2.685 2.685 0 0 1 2.004.815c.527.54.81 1.254.79 1.99l-.008.257a.096.096 0 0 1-.1.094H7.02c.024.46.244.892.61 1.197a1.97 1.97 0 0 0 1.322.482c.347.015.69-.067.988-.235.255-.167.472-.38.64-.626a.102.102 0 0 1 .127-.032l.659.321a.095.095 0 0 1 .05.057.089.089 0 0 1-.01.073c-.506.828-1.45 1.33-2.462 1.308l-.004-.003zm-1.897-3.34h3.593a1.653 1.653 0 0 0-.585-1.084 1.79 1.79 0 0 0-1.205-.432c-.45 0-.883.168-1.204.467a1.658 1.658 0 0 0-.599 1.05zm12.053 5.363h-.81a.096.096 0 0 1-.099-.093v-7.41c0-.051.045-.093.1-.093h.81c.054 0 .098.042.098.093v.77a2.18 2.18 0 0 1 .86-.718c.364-.18.769-.271 1.18-.27.779-.016 1.53.282 2.062.82.554.546.83 1.222.83 2.03a2.733 2.733 0 0 1-.837 2.024 2.819 2.819 0 0 1-2.057.824 2.817 2.817 0 0 1-1.18-.246 2.103 2.103 0 0 1-.859-.696v2.872a.096.096 0 0 1-.098.093zm3.43-3.476c.378-.375.582-.878.567-1.396a1.891 1.891 0 0 0-.57-1.395 2.015 2.015 0 0 0-1.41-.568c-.532 0-1.042.205-1.411.568a1.89 1.89 0 0 0-.561 1.395c-.015.519.19 1.021.569 1.396.37.362.879.567 1.41.567.533 0 1.042-.205 1.412-.567h-.005zm5.372 1.453c-.857 0-1.56-.268-2.11-.802-.552-.535-.828-1.217-.83-2.047 0-.814.272-1.492.817-2.034a2.792 2.792 0 0 1 2.051-.815 2.685 2.685 0 0 1 2.004.815c.527.54.811 1.254.79 1.99l-.008.257a.096.096 0 0 1-.1.094h-4.535c.023.461.243.894.61 1.2a1.97 1.97 0 0 0 1.322.482c.347.015.69-.067.988-.236.256-.166.473-.378.64-.625a.102.102 0 0 1 .127-.033l.66.322a.095.095 0 0 1 .05.056.089.089 0 0 1-.01.074c-.507.828-1.45 1.33-2.462 1.308l-.004-.006zM26 7.579h3.592a1.654 1.654 0 0 0-.587-1.082 1.837 1.837 0 0 0-2.407.033 1.658 1.658 0 0 0-.598 1.05zm8.623-2.216v.772a.091.091 0 0 1-.032.068.102.102 0 0 1-.075.025 2.003 2.003 0 0 0-.178-.007 1.566 1.566 0 0 0-1.256.543c-.309.364-.463.844-.463 1.442v2.497a.096.096 0 0 1-.098.093h-.81a.096.096 0 0 1-.1-.093V5.439c0-.051.045-.093.1-.093h.798c.054 0 .098.042.098.093v.871c.133-.32.377-.59.692-.763.322-.19.694-.29 1.073-.29l.16.013c.051.004.09.044.091.093zm4.37 5.316a.11.11 0 0 1-.066.103c-.26.1-.538.146-.817.137-.546 0-.974-.15-1.285-.448-.31-.298-.465-.714-.462-1.246V6.21h-.79a.096.096 0 0 1-.1-.093v-.677c0-.051.045-.093.1-.093h.79V3.615c0-.052.044-.094.099-.094h.81c.055 0 .099.042.099.094v1.73h1.53c.054 0 .098.043.098.094v.677a.096.096 0 0 1-.099.093h-1.53v2.883c0 .321.077.556.23.705.155.15.398.224.73.225.176.004.35-.028.512-.093a.104.104 0 0 1 .095.004.093.093 0 0 1 .047.078l.01.668z" fill-rule="nonzero"></path>
#  </svg>
#  </a>
#  <a href="/profile/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" onclick="naver.kin.pc.common.nClicks('end*a.profile', '', '', event);" target="_blank">장종현 변호사님 답변</a></p>
#  <div class="c-heading-answer__icons">
#  </div>
#  <div class="c-userinfo">
#  <span class="c-userinfo__item"><em class="text-color--primary">법무법인 행복</em></span>
#  <span class="c-userinfo__item">받은감사수 <em>28</em></span>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="_endContents c-heading-answer__content">
#  <div class="_endContentsText c-heading-answer__content-user"><div class="se-viewer se-theme-default" lang="ko-KR"> <!-- SE_DOC_HEADER_START --> <!--@CONTENTS_HEADER--> <!-- SE_DOC_HEADER_END --> <div class="se-main-container"> <div class="se-component se-text se-l-default" id="SE-2b62e5fe-45e3-4330-9e31-01fc78f9ab32"> <div class="se-component-content"> <div class="se-section se-section-text se-l-default"> <div class="se-module se-module-text"> <!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align-" id="SE-fd5d1c08-43ea-47ab-8264-07b491d5ed3b" style=""><span class="se-fs- se-ff-" id="SE-d9d79912-4d61-41bd-90a1-88918717f5e3" style="">안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align-" id="SE-2f5e3698-a2dd-4fbb-8196-83de5f296101" style=""><span class="se-fs- se-ff-" id="SE-9f276a07-afac-47e5-8c3f-fe4df2278316" style="">​</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align-" id="SE-50bbe66d-67d5-40cb-85bd-00f60999b45e" style=""><span class="se-fs- se-ff-" id="SE-1f914c71-a1df-4228-b298-164a7e5ad953" style="">민사소송에서 승소하여 채무자의 급여 내지 재산에 대하여 압류 및 추심 등의 강제집행절차를 진행할 수 있습니다.</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align-" id="SE-85817a47-66a6-4095-b927-fcb57be25479" style=""><span class="se-fs- se-ff-" id="SE-a997b6c1-2347-451a-b73e-78d641e3b6aa" style="">​</span></p><!-- } SE-TEXT --><!-- SE-TEXT { --><p class="se-text-paragraph se-text-paragraph-align-" id="SE-d071c243-9161-43d3-bba8-54466d13e8b2" style=""><span class="se-fs- se-ff-" id="SE-b0f9c3b3-3f1e-4469-90a1-430c65390def" style="">강제집행대상이 없는 경우에는 실질적인 채권만족이 곤란하게 되며, 이런 경우에는 채무자의 재산확인을 위해 법원에 재산명시신청, 재산조회신청을 하게 되며, 더불어 채무불이행자명부등재신청을 통해 간접강제하는 절차를 밟을 수가 있습니다.</span></p><!-- } SE-TEXT --> </div> </div> </div> </div> </div></div></div>
#  <div class="business-card">
#  <div class="business-card__thumb">
#  <a class="business-card__thumb_img" href="/userinfo/expert/index.naver?u=ZOyoKXXwJit%2BzpbT6ISNHWmVYZw8C1dIyk%2Fx9d0x6OQ%3D" onclick="naver.kin.pc.common.nClicks('end.nmbimg', '', '', event);" style="background-image: url('https://kin-phinf.pstatic.net/exphoto/expert/78/Vm5_1628126737850.jpg')" target="_blank"></a>
#  </div>
#  <div class="business-card__content">
#  <div class="business-card__content-info">
#  <strong class="business-card__name" onclick="naver.kin.pc.common.nClicks('end.nmbtxt', '', '', event);">
#  				장종현
#
#  					변호사
#  			</strong>
#  <div class="business-card__info">
#  <em class="business-card__info-brand">법무법인 행복</em>
#  <span class="business-card__info-contact">02-534-2200</span>
#  </div>
#  <div class="business-card__description">
#  <p class="business-card__detail business-card__detail--line-2">지식iN 변호사 답변은 대국민 법률 상담에 뜻을 둔 변호사의 지식기부로서 서울지방변호사회와 네이버의 제휴를 통해 변호사가 직접 정확하고 신뢰할 수 있는 답변을 제공합니다.</p>
#  </div>
#  </div>
#  <div class="business-card__group-button">
#  <span class="business-card__button is-disabled" role="button">
#  <span class="business-card__button-inner">
#  <i aria-hidden="true" class="icon icon_reservation"></i><span class="business-card__button-name">예약</span>
#  </span>
#  </span>
#  <a class="business-card__button" href="http://cafe.daum.net/happylawer" onclick="naver.kin.pc.common.nClicks('end.nmbhome', '', '', event);" role="button" target="_blank">
#  <span class="business-card__button-inner">
#  <i aria-hidden="true" class="icon icon_homepage"></i><span class="business-card__button-name">홈페이지</span>
#  </span>
#  </a>
#  <a class="business-card__button" href="https://map.naver.com/v5/search/%EC%84%9C%EC%B4%88%EC%A4%91%EC%95%99%EB%A1%9C%20119/address/14139095.598767582,4507970.972918745,%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%20%EC%84%9C%EC%B4%88%EA%B5%AC%20%EC%84%9C%EC%B4%88%EC%A4%91%EC%95%99%EB%A1%9C%20119,new?c=14139065.3309980,4507970.1451432,19,0,0,0,dh" onclick="naver.kin.pc.common.nClicks('end.nmbmap', '', '', event);" role="button" target="_blank">
#  <span class="business-card__button-inner">
#  <i aria-hidden="true" class="icon icon_location"></i><span class="business-card__button-name">위치</span>
#  </span>
#  </a>
#  </div>
#  </div>
#  </div>
#  <div class="c-guideline c-guideline-default">
#  <strong class="c-guideline__title"><i class="icon_notice"></i>알아두세요!</strong>
#  <ul class="c-guideline__list c-guideline__list--number">
#  <li class="c-guideline__item"><i class="c-guideline-symbol">1.</i>사건의 구체적 사실과 정황 등에 따라 법규정 해석에 대한 이견이 있을 수 있습니다. 상이한 이견을 모두 수렴하지는 않습니다.</li>
#  <li class="c-guideline__item"><i class="c-guideline-symbol">2.</i>답변은 질문자가 질의한 내용을 기반으로 한 답변 변호사 소견으로, 답변과 관련하여 답변 변호사나 사업자의 법률적 책임이 없음을 알려드립니다.</li>
#  <li class="c-guideline__item"><i class="c-guideline-symbol">3.</i>자세한 사항은 법률사무소를 방문하여 법률상담을 하시기 바랍니다.</li>
#  <li class="c-guideline__desc">위 답변은 답변작성자가 경험과 지식을 바탕으로 작성한 내용입니다. 포인트로 감사할 때 참고해주세요.</li>
#  </ul>
#  </div>
#  <p class="c-heading-answer__content-date">11시간 전</p>
#  </div>
#  <div class="c-userinfo-answer _answerBottom">
#  <div class="c-userinfo-answer__left">
#  <div class="likeit_user _answerLikeArea" data-answer-no="1" id="answerLikeArea_1">
#  <div class="u_likeit _reactionModule" data-cid="10000009_00001911d61e_1" data-display="inline-block" data-pid="10000009_00001911d61e" data-sid="KIN" style="display:none;">
#  <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" href="javascript:void(0)" onclick="naver.kin.pc.common.nClicks('end*a.face', '', '', event);" role="button">
#  <span class="u_likeit_icons _icons">
#  <span class="u_likeit_icon" style="z-index:2;"><span class="u_likeit_blind">표정</span></span>
#  <span class="u_likeit_icon" style="z-index:1;"><span class="u_likeit_blind">표정</span></span>
#  </span>
#  <span class="u_likeit_blind" id="u_likeit_title_1">좋아요 평가하기</span>
#  <span class="u_likeit_text _count">표정</span>
#  </a>
#  <ul aria-labelledby="u_likeit_title_1" class="u_likeit_layer _faceLayer" role="radiogroup">
#  <li class="u_likeit_list like" role="presentation">
#  <a aria-checked="false" class="u_likeit_list_button _button" data-log="end*f.like|end*f.likeoff" data-type="like" href="javascript:void(0)" role="radio">
#  <span class="u_likeit_list_name _label">좋아요</span>
#  <span class="u_likeit_list_count _count"><span class="u_likeit_blind">총:</span>0</span>
#  </a>
#  </li>
#  <li class="u_likeit_list useful" role="presentation">
#  <a aria-checked="false" class="u_likeit_list_button _button" data-log="end*f.useful|end*f.usefuloff" data-type="useful" href="javascript:void(0)" role="radio">
#  <span class="u_likeit_list_name _label">유익해요</span>
#  <span class="u_likeit_list_count _count"><span class="u_likeit_blind">총:</span>0</span>
#  </a>
#  </li>
#  <li class="u_likeit_list haha" role="presentation">
#  <a aria-checked="false" class="u_likeit_list_button _button" data-log="end*f.haha|end*f.hahaoff" data-type="haha" href="javascript:void(0)" role="radio">
#  <span class="u_likeit_list_name _label">재밌어요</span>
#  <span class="u_likeit_list_count _count"><span class="u_likeit_blind">총:</span>0</span>
#  </a>
#  </li>
#  <li class="u_likeit_list toobad" role="presentation">
#  <a aria-checked="false" class="u_likeit_list_button _button" data-log="end*f.toobad|end*f.toobadoff" data-type="toobad" href="javascript:void(0)" role="radio">
#  <span class="u_likeit_list_name _label">동의못해요</span>
#  <span class="u_likeit_list_count _count"><span class="u_likeit_blind">총:</span>0</span>
#  </a>
#  </li>
#  <li class="u_likeit_list likead _button" role="presentation">
#  <a aria-checked="false" class="u_likeit_list_button _button" data-log="end*f.likead|end*f.likeadoff" data-type="likead" href="javascript:void(0)" role="radio">
#  <span class="u_likeit_list_name _label">광고같아요</span>
#  <span class="u_likeit_list_count _count"><span class="u_likeit_blind">총:</span>0</span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <a aria-haspopup="true" aria-pressed="false" class="user_display _likeUserListBtn" href="javascript:void(0)" onclick="naver.kin.pc.common.nClicks('end*f.more', '', '', event);" role="button" style="display:none;">
#  <span class="sp_likeit ico_ellipsis"><span class="blind">사용자 표시</span></span>
#  </a>
#  </div>
#  <button aria-controls="answerCommentListArea" aria-expanded="false" aria-selected="false" class="button_compose _commentBtn" id="cmtstr_1" onclick="naver.kin.pc.common.nClicks('end*a.comment', '', '', event);return false;" role="option" type="button">
#  <i aria-hidden="true" class="icon icon_compose_opinion"></i><span class="button_compose_text _commentText">댓글</span>
#  </button>
#  </div>
#  <div class="c-userinfo-answer__right">
#  <div class="c-userinfo__button-point">
#  <a aria-describedby="tooltipPointText" class="button_point _pointGiftButton" data-answer-no="1" data-dir-id="60221" data-doc-id="420599326" href="#" onclick="naver.kin.pc.common.nClicks('ptxb.pthx', '', '', event);" role="button">포인트로 감사</a>
#  <div aria-expanded="false" aria-hidden="false" class="tooltip_point _pointGiftTooltip" role="tooltip" style="display:none;">
#  <div class="tooltip_text" id="tooltipPointText">도움이 되었다면 포인트로 감사한 마음을 전해보세요.</div><button class="button_close _pointGiftTooltipClose" onclick="naver.kin.pc.common.nClicks('ptxb.tooltip', '', '', event);" type="button"><span class="blind">포인트로 감사 툴팁 닫기</span></button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="c-opinion _commentListArea" data-answer-no="1" data-thanks-message="" style="display:none;"></div>
#  </div>
#  </div>]

# %%
ans_list[0].find('div', class_='se-module se-module-text').text
# Out:
# ' 안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.\u200b민사소송에서 승소하여 채무자의 급여 내지 재산에 대하여 압류 및 추심 등의 강제집행절차를 진행할 수 있습니다.\u200b강제집행대상이 없는 경우에는 실질적인 채권만족이 곤란하게 되며, 이런 경우에는 채무자의 재산확인을 위해 법원에 재산명시신청, 재산조회신청을 하게 되며, 더불어 채무불이행자명부등재신청을 통해 간접강제하는 절차를 밟을 수가 있습니다. '

# %%
df1
# Out:
#    변호사이름                                              프로필링크
# 0    김광웅  https://kin.naver.com//profile/index.naver?u=o...
# 1    권광중  https://kin.naver.com//profile/index.naver?u=6...
# 2    이재호  https://kin.naver.com//profile/index.naver?u=7...
# 3    박준상  https://kin.naver.com//profile/index.naver?u=c...
# 4    김낙의  https://kin.naver.com//profile/index.naver?u=w...
# ..   ...                                                ...
# 72   박진세  https://kin.naver.com//profile/index.naver?u=d...
# 73   권희영  https://kin.naver.com//profile/index.naver?u=e...
# 74   안지성  https://kin.naver.com//profile/index.naver?u=i...
# 75   김도훈  https://kin.naver.com//profile/index.naver?u=D...
# 76   이도형  https://kin.naver.com//profile/index.naver?u=z...
#
# [77 rows x 2 columns]

# %%
df1= pd.read_csv('민사변호사_프로필_링크.csv')

# %%
df1['프로필링크'].values[0]
# Out:
# 'https://kin.naver.com//profile/index.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D'

# %%
# ans_link = []
qna_data = []

for href in tqdm(df1['프로필링크'][0:1]):
    html = requests.get(href)
    soup = bs(html.text, 'html.parser')
    ans_href = soup.find('div', class_='container-fluid-content__right').find('span', class_='more').find('a')['href']   
    url2 = 'https://kin.naver.com/' + ans_href
    html = requests.get(url2)
    soup = bs(html.text, 'html.parser')
    
    # 답변수를 20으로 나누어 페이지 수 계산
    page_num = int(soup.find('div', class_ =  'container-fluid-content__left').find_all('span', class_='num')[1].text[1:-1].replace(',', '') ) // 20
    
    # 페이지별로 20개씩
    for p_num in tqdm(range(1, page_num+1)):
        url3 = url2 + '&page=' + str(p_num)
        
        html = requests.get(url3)
        soup = bs(html.text, 'html.parser')
#         cotent_soup = soup.find('div', class_='container-fluid-content__right')
        cotent_soup = soup.find('table', class_='boardtype2 th_border')
        for i in range(0, 20) :           
            try :
                cat = cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[i].find('td', class_='field').find('a').text
                con = cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[i].find('td', class_='title').text
                link = cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')[i].find('td', class_='title').find('a')['href']
                link = 'https://kin.naver.com' + link
            except :
                continue
            #             ans_link.append([cat, con, link])
                    
            # 분류가 민사이면 지식인에 들어감
            if cat == '민사소송':               
                html = requests.get(link)
                soup = bs(html.text, 'html.parser')
                
                try :
                    title = soup.find('div', class_='title').text
                    title = re.sub('[^ㄱ-ㅎ가-힣0-9 ]', '', title)
                    
                except :
                    title = ''
                    
                try :
                    content = soup.find('div', class_='c-heading__content').text
                    content = re.sub('[^ㄱ-ㅎ가-힣0-9 ]', '', content)
                    
                except :
                    content = ''
                    
                try :
                    ans_list =soup.find_all('div', class_='answer-content__list _answerList')
                    ans_text = []
                    for ans in ans_list :
                        ans_text.append(ans.find('div', class_='se-module se-module-text').re.sub('[^ㄱ-ㅎ가-힣0-9 ]', '', text))
                        
                except :
                    ans_text = ''
                    
                qna_data.append([title,  content, ans_text])
                
df2 = pd.DataFrame(qna_data, columns=['제목', '본문', '답변'])
df2
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/131 [00:00<?, ?it/s]
#                                                     제목  \
# 0                                         촉법소년 사기 민사소송
# 1
# 2
# 3                                              민사소송 소장
# 4                   형사로 상대방 벌금 받았을 경우 민사로 얼마나 청구할수 있나요
# ..                                                 ...
# 308                                    전치 4주 상해 죄 민사소송
# 309  110만원 정도를 사기를 당했는데 사이버 수사대에 신고를하면 경찰에서 소송을 하는건...
# 310                                     이행권고결정 정본 받았는데
# 311                          소송가액보다 더 많은 금액이 판결될 수 있나요
# 312                                            민사 조정 후
#
#                                                     본문  답변
# 0    피의자는 사기쳤을 당시에 촉법소년이었습니다지금은 아님사기친 금액은 문상 3만원이고 ...
# 1                                                       []
# 2                                                       []
# 3    피고가 미성년자라 소장 피고 기재란에 미성년자 이름을 쓰고 밑에 법정대리인 ㅇㅇㅇ으...
# 4    상대방 2명이 주거침입과 쌍방폭행으로 벌금 각각 200씩 받았는데 변호사 선임해서 ...
# ..                                                 ...  ..
# 308  작년 3월 폭행을 당해 전치 4주 코뼈 골절 을 받았습니다이제 판결이 끝나고 벌금형...
# 309  110만원 정도를 사기를 당했는데 사이버 수사대에 신고를하면 경찰에서 소송을 하는건...
# 310  임금 체불 민사로 이행권고결정 정본 받았습니다이걸로 채당금 받을수 있는건가요확정판결...
# 311  가끔 기사에 죄가 중해 1심보다 더 많은 벌금이 판결됐다는 기사를 본 거 같습니다민...
# 312  소송 비용은 각자 부담이라고 명시하고 끝났습니다 지급명령 신청 하느라 송달료 6만원...
#
# [313 rows x 3 columns]

# %%
for content in df2['제목']:
    print(re.sub('[^ㄱ-ㅎ가-힣0-9 ]', '', content))
# Out:
# 촉법소년 사기 민사소송
#
#
# 민사소송 소장
# 형사로 상대방 벌금 받았을 경우 민사로 얼마나 청구할수 있나요
# 물품값대여금외상값 합쳐서 대여금반환소송으로 통칭해서 소송했는데
# 민사소송 저는 피고이고 1심불참 서류를 못받았어요 불복으로 항소장제출 오늘 석면준비이유서제출하라는등기보낸거 같아요 항소이유서 어떻게 준비해야
# 사기죄 민사소송
# 민사재판 날짜가 잡혀 재판받으러 가야하는데 피해자도 참석하나요 피해자랑 말하고 대화해야하나요 아님 재판장님말씀에만 말하면되나요
# 인터넷 사기로 민사소송진행하려는데 손해배상인지 부당이득인지 알려주세요 내공100
# 손해배상청구
# 이름과 주만등록번호만 알고 있는데 민사소송800만원 가능한지요 주소모름소송을 위해 필요한 최소 정보는 무엇을 있을까요
# 사이버모욕죄 민사소송 질문
# 소액청구소송 변호사선임
# 변호사 소송수임료 문의
# 제소전 화해
# 안녕하세요 불법통화녹음  기준 궁금 합니다
# 상간녀 소송 승소하고 남편과 잘 지내는 분들께 질문
# 민사소송관련
# 소액민사소송
# 폭행 상해죄 민사 준비방법
# 사기죄 불송치혐의없음 받았는데 민사 가능한가요
# 민사 판결 위반시 형사처벌 가능 여부
# 서울남부지방법원 변호사님 소개부탁드립니다
# 민사조정과 화해권고의 차이가 무엇인가요
# 명도소송 관련 질문드립니다
# 강제추행 피해자이고 민사소송 관련 질문드려요
# 부당이득소송 이행권고결정 후에 해야될 조치
# 사실조회 신청
# 민사재판 소송사기죄
# 녹취록 증거 인정 여부
# 석명준비명령
# 명도소송중인데 원고로부터준비서면이왔는데피고도준비서면을꼭보내야하나요
# 사문서에 관련한 민사소송인데 재판부 직권으로 조정에 회부가 되었습니다 그럼 직접 참석하여 조정할 의사가 없다고 밝혀야 예의 인가요 아님 조정
# 절도 약식명령 후 민사소송
# 층간소음 민사소송 진행중에 이사하더라도 소송은 계속 진행되는건가요
# 성폭력 촬영물이용협박죄  1심 항소심 민사소송 합의
# 대여금소송
# 명도소송비용 처리
# 소액사기 변론기일 이후에는 어떻게 해야되나요
# 민사 부당이득금 소송에서 소가에 위자료를 포함시켜 적나요
# 민사 소송할 때 관할 법원에서만 소송이 가능한가요
# 상해 합의금
# 상속포기 후 민사소송
# 형사소송 합의를 하면 추가적으로 민사소송은 불가능한가요
#
# 민사소송 정신과 진단서 질문드립니다
# 녹취록 증거 효력 비용관련형사 민사 각각
# 민사 항소한 후 항소 이유서를 제출하라는 석명준비명령이 왔는데 이 기간을 조금 넘어도 항소 이유서를 제출할 수 있나요
# 민사소송 답변서를 법원에만 내면 되나요
#
# 민사소송 판결후 손해배상액 납부일
# 광주지방법원사건민사소송변호사알아보고있는데 부산변호사고용해도되나요
# 민사소송 진행중인데 다음순서는 어떻게 되는지 궁금합니다
# 민사소송 답변서 이후 재판일이 안잡혀요
# 전세금반환소송
# 공유물분할청구소송시 내용증명 필요여부
# 상대방이 민사소송 손해배상 청구하면
# 민사소송 주소불명 주소보정명령등본
# 부동산 가압류 해제건
# 소액 손해배상청구소송 변호사비용 기타 질문
# 같은 건으로 고소인이 절 고소하고 민사 손해배상 청구 소송까지 걸었습니다 민사는 변호사를 선임했는데 형사는 선임하지 않아 저 혼자 피의자 조사
# 민사소송대여금반환청구소송
# 형사고소했다가 증거불충분 불기소 처분 나온 이후
# 민사소송 및 반소 궁금합니다
# 대여금 청구소송 변론기일연기
# 대여금 반환소송 승소후 질문
# 명도소송후 이사비 지급 문제 피고입니다
# 소송할때 둘다 증거가 없으면 판사님이 어떻게 판결내리나요
# 형사소송 승소 후
# 부동산인도명령 신청을 전자소송으로 냈습니다그저께 내서 어제 인용되고 송달되었다고 뜨는데요신청인인 저한테도 송달한거 같은데 전자문서 들어온게 없네요 혹시 신청인한테도 우편으로 송달하나요제가 전자소송 주소를 고치기가 귀찮아서 이사오기 전 주소로 되어있는데 지금 주소로 고쳐야하는지 아니면 전자문서로 송달이 오는지 궁금합니다만약 신청인한테도 우편송달하는 것이라면 주소를 고쳐서 받아야할거 같은데 어떻게 고쳐야하나요
# 대여금 반환소송에 대하여 질문드립니다
# 사실혼 인정 가능하나요
# 상간녀 소송당하지 않겠죠
# 가압류있는땅 공유물분할 청구소송으로 말소
# 나홀로소송  금전청구소송 유형 질문입니다
# 위증죄 고소에 대하여
# 민사에서 항소장내고 항소이유서는 얼마안에 내야하나요
# 대여금반환소송
# 전자소송 대여금 피고 전화번호 오기입
# 무협의 받은 가해자가 피해자에게 손해배상 청구 가능한가요
# 대여금 소송 무변론 기일 지정 문의
# 양수금 판결은 소멸시효연장 사유가 아닌가요
# 공유물 분할 청구 소송이 들어왔는데요
# 민사소송 시  영상 제출 관련 문의입니다
# 민사소송에서 패소할 경우 소송비용을 물어줘야 되잖아요그럼 원고가 승소할 경우 피고가 원고의 소송비용을 물어줘야 되는 건가요 소송비용에는 변호사비용도 있잖아요 만약 원고가 변호사 수임료를 엄청 비싸게 했다하더라도 그 비용을 전부 물어줘야 되나요
# 민사소송 변론기일통지서 받은 후 변호사 선임 가능여부
# 형사소송은 패소시 상대방 변호사 비용이 안든다고 하던데
# 유부남 유부녀가 바람낫을때
# 형사소송 승소 이후 민사소송때 국선 변호사님 선임 한 이후 가해자들을 법원에서 소환할때 피해자 개인정보도 공개가되나요
# 민사소송 보정명령 받고 피고 주소 수정
# 모욕죄 민사소송
# 모욕죄 공연성 결여시 질문
# 녹취록없이 녹음파일만으로 증거체택이 가능한가요
# 상간녀소송 가능한가요
# 재산분활소송에 들어가는데요 아파트 시세로 들어가는건가요 매매가로 들어가는건가요 알고싶네요
# 대여금반환청구소송 소액도 가능한가요
# 강제집행면탈죄 질문입니다
# 명도소송 중 임대
# 대여금소송 사실조회신청
# 나홀로 민사소송 중 피고의 답변서를 받은 경우
# 교통사고 개인소송 법무사가면 송장써주나요
# 상간녀 민사소송 위자료
# 민사 조정법정에서요 조정합의에 도장 찍었습니다 그런데 다음날 취소할수 있나요
# 상간녀도 나랑 똑같은 고통주고 싶어요
# 상간 피고 소송방어관련하여 문의드립니다
# 조정의 구속력 부분에 대해 질문 드립니다
# 민사소송 피고답변서 이후 조치
# 친생자관계부존재 유전자검사에 대해 질문합니다
# 명도소송 맡길 천안변호사 추천해주실 수 있나요
# 명도소송과 손해배상
# 월세 보증금 반환 민사소송 중 일부 금액 반환에 관한 건
# 민사소송 패소 후 원고에게 금액을 지불해야 하는데 계좌나 전화번호를 모릅니다
# 민사 피고인 변론기일 불출석 질문
# 문서제출명령을 신청했더니 판사가 피고에게 임의제출하라고 하여5개중 3개만 제출하고 나머지는 없다고답변했습니다2개도 제출하게 하려면 나머지 2개항목에 대해새로 문서제출명령을 신청해야 하나요아니면 기존 신청한것중 2개만 문서제출명령을 내려달라고 하나요
# 민사소송에 대하여
# 녹취록
# 민사재판 확정일민사재판을 2년여년간 진행중 2회의조정 불성립되서 법원에서 2021년11월 9일 강제조정으로 종국 통보되었습니다 확정판결은 언제로 봅니까 나의사건에 확정판결표시가되나요
# 재산 증여 관련 소송
# 유류분반환청구
# 사해행위 취소소송
# 민사소송에서 선임한 변호사님이 상대측이 구석명신청을 했는데 반박을 하지 않아 2회 속행이 되었고 이것을 변론기일이 얼마남지 않은 날 알게 되었는
# 돈안내는세입자 명도소송 결과나오기까지 냅둬야되나요
# 지상물매수청구권 건물 감정인 질문입니다
# 형사에서 무죄가 나와도 민사소송 걸어서 법원까지 갈 수 있나요
# 명도소송 의견서 제출
# 민사소송 공시송달 후 첫재판
# 폭행민사소송 손해배상청구
# 기소유예 와 교육조건기소유예 의 차이
# 민사 소송시 벌금 낼 능력이 안된다면 어떻게 되나요
# 대여금 반환 청구소송을 진행중인데요
# 통화녹취록 증거효력있나요
# 상간소 맞소송시
# 재산분할시 기여도 문의
# 오피스텔 계약금 반환청구 소송중입니다
#
# 민사 소송 위자료
# 미성년자 상간녀 소송 만 15세 이하에게 걸수있나요
# 민사소송 변호사
# 상간녀소송 진행 중이고 자백 증거 등 이미 다 제출하고 기일까지 잡힌 상태입니다 피고쪽에서도 변호사 선임했고 자백을 이미 다 한 상태라 딱히 부인하거나 그러진 않을 것 같은데 위자료 어느정도 나올까요 성관계 했고 아기가 있는 유부남인 것도 다 아는 상태에서 만난 거라고 인정했습니다 그리고 위자료 판결이 나면 한번에 다 받을 수 있는지 아니면 나눠서 받을 수도 있는지도 궁금합니다
# 녹취록을 부인하거나 민사 소송 중에 허위와 위증 사실은 어떻게 대처
# 집단소송 뒤 승소하면 소송에 참여하지 않은 다른 피해자들도 받을 수 있나요
# 상간녀 패소
# 부동산관련 소송할려하는데
# 대여금 소송 시 입출금내역만 있으면 대여금반환 소송에 분리한가요
# 민사소송 접수전 소송취하시 변호사 선임비  반환
# 데이트폭력 형사고소 후 2년
# 민사 1차 변론기일 이후에 낸 준비서면은 그냥 참고서류 수준이 되는 것인가요
# 민사 변론기일에 진행이 어떻게 되나요
# 양육비 과청구건
# 민사 재판 방청
# 재판이후 변호사비용 청구
# 공매 명도소송 피고를 부부로 해야할까요 단독으로 해도 될까요
# 대여금 민사소송 종결 이후
# 사기죄 형사소송후 민사소송
# 명예훼손으로 민사상 손해배상 청구
# 유류분반환소송과 가압류해놓은 재산
# 상속분할소송과 유류분소송
# 민사소송 항소 관련 질문입니다
# 형사재판에서 업무상 위력 추행과 명예훼손으로 가해자를 8개월 실형선고를 내렸습니다 민사소송 관련하여
# 대여금 민사소송 도움 부탁드립니다
# 대여금 민사소송
# 원고에게 민사소송을 당해 답변서를 작성중에있습니다 원고가 정신적 피해로 위자료 80만원을 주장했습니다 피고는 원고의 공갈로 인해 정신적 피해가
# 상간녀위자료소송
# 녹취록을 제출해도 상대방이 인정안하면증거가 안되나요
# 대여금반환청구소송
# 민사전자소송 조정성립 이후
# 민사소송에서 변호사 비용은 어떻게 드나요
# 상간녀에게 위자료 받을 수 있나요
# 공시송달 알림
# 상간녀 구상권 청구소송 승소 가능할까요
# 녹취록
# 상간녀 소송 문제
# 유류분반환청구소송 관련으로 몇가지 질문드리겠습니다1 피증여자가 증여받은 재산을 배우자나 제3자로 명의이전했을 경우 유류분반환청구소송을 할 수 있나요2 유류분반환청구소송의 비용과 기간이 어떻게 되나요변호사선임비3 100승소 가능한가요 패소하는 경우가 있다면 어떤 경우인지도 알려주세요
# 임대인분의 명도소송
# 형사고소 후 민사 진행이 궁금합니다
# 민사 소송시 주소지
# 민사소송 이행권교결정 송달 후 이의신청
# 사기죄 민사소송으로 부부재산에 피해가나요
# 위자료까지 청구하려면 배상명령신청 안하고  민사소송부터 할까요
# 민사소송 취하와 변호사 선임비용
# 형사 후 민사 소송을 하려 합니다
# 점유이탈물 횡령죄 민사소송 방법
# 요약쟁점정리서면 및 소장 답변서 문의
# 민사소송 변호사없이 금액 얼마 나올까요
# 민사소송 진행중 청구취지 청구원인 변경
# 상간녀소송대응 무료상담
# 민사소송 변호사 비용
# 민사소송 패소하면 상대방 변호사 성공보수까지 물어줘야 하나요
# 상간녀상간남 위자료청구
# 민사소송 변호사 질문
# 한정상속승인 변호사통해 진행할경우 비용이 얼마나들까요부모님은 이혼한상태라 배우자가없어서저와 제동생이 있고 제 밑으로는 자녀가 둘이있습니다
# 상속 한정승인 한 경우 민사 제소시 상속인 모두 다 출석여부
# 민사 승소 후 형사고소
# 형사고소와 민사고소 궁금합니다
# 상간녀소송 관련 패소 이후 재소송 승소 가능성 알고싶습니다
# 안전한 서울민사변호사 무료상담좀 민사소송 부동산 상속 명도소송 손해배상 전부 포함요
# 아동학대 민사소송으로 5명의 아이가 민사소송을 했어요형사소송에서는 1심 징역 2심 집행유예가 나왔는데2명의 아이는 청구한 그대로 받아들여졌고저희아이는 학대횟수나 학대수위가 제일 높은데판사마다 재량이달라서 저희아이가 다른아이들보다 금액이 낮게 판결날수도 있는건가요
# 제소전화해출석을 거절할때
# 폭행 소액민소송 준비중 위자료 청구 소멸시효 질문
# 폭행가해자 민사소송할려고 합니다
# 민사소송을 진행하고 조정
# 외도대한 민사소송하려고하는데 안산 시흥 아는곳있으세요 전문가 민사소송합의금받으려고요 추천좀 부탁드려요
# 업무상 손해배상 청구 소송으로 변론기일 피고 불출석해도 괜찮은가요
# 근로자입니다 임금체불 형사항소 및 민사항소 문의드립니다
# 대여금반환소송
# 민사소송 승소하는법  기각시키는법
# 여성변호사를 인천민사변호사 상속 부동산 명도 소송을 성실하게 해줄분요
# 박소연동물연대 대표에게 댓글 민사소송 당했어요
# 민사소송이겨도 형사건에서 뒤집힌경우
# 민사소송
# 형사재판 후 민사소송 질문드립니다
# 금전소비대차 계약서로 민사소송 진행
# 친권 양육권 분리가능여부
# 자녀가 부모 양육비 청구 소송 가능할까요
# 민사소송 사기죄 여쭤봅니다
# 1심 민사재판에 기간은 보통 몇달정도 소요되나요
# 소송 시 특유재산
# 모욕죄 기소유예 민사소송가능한가요
# 전세 월세 이중계약 민사 소송 질문드립니다
# 착오송금 부당이득반환청구소송
# 변호사가 임의로 조정에 대한 권리를 판단 할 수 있나요
# 민사 소송할 때 피해자 측 변호사
# 상간남 소송을 당하면 여자쪽에서도 고소하나요
# 조정 불이행
# 상간소송 피고가 두명 원고일부승소판결
# 상간자 소송 피고 입장에서 원고가 제출한 증거 볼수있나요
# 자녀성본변경
# 명도소송을 당했는데 판사님 조정으로 이사비용 받았습니다손배 소송 진행할수 있는지
# 명도소송해서 강제집행까지 들어간 비용 받을벙법
# 이 경우에도 녹취록 증거가 될수 있나요
# 안녕하세요 민사 소송 관련입니다
# 이름 주민번호 다른 상간남 소취 후 재소송
# 명도 소송이 뭐예요
# 민사 소송 관련
# 불기소처분을 받은 내용을 알 수 있는 증거를 제출하라는 석면준비명령을 받았는데준비서면은 이미 제출했습니다 어떤 식으로 제출해야하나요 전자소송진행중이며 피고입니다
# 부당이득금에 대한 반환소송이 가능한지요
# 민사소송
# 패소 후 소송비용액 확정 받았는데 이거 어떻게 지불 해야 하나요
# 공유물분할 소송비용
# 학교폭력 미성년자 민사소송
# 민사소송
# 증거불충분으로 혐의없음 받은 형사고소
# 외도는 어디까지해야 상간녀소송할수 있나요남편이 직장여직원하고 수시로 통화하고 카톡하고 남편이 보고싶다하면 여자는 당연한거라고하고 남편이 이러는거 병인가봐라고하고 여자는 아이좋아라하고 같이놀러가고싶다라고 하면 여자는 옆에만 있으면되냐고 하는데 이것도 소송하면 되나요 지금 남편은 사소한 문제로 집에서 쓰는 카드달라고하는데 이혼하자고 할거같네요늦은밤에 카톡하고 남편은 이걸 다 지우네요이게 몰래 증거수집한거라 소송시 불리할까요
# 민사소송
# 친양자입양 소송진행중입니다친부가 십년넘게연락두절에 생사도모르고 살아서 친양자입양동의서가없는 상태에서 소송진행중입니다입양부모교육 완료했고 심문기일 잡혀서 엊그제 법원출석했어요 친부송달자체가안된다고 판사님이 빠른시일안에 판결문 보내주신다고하고 심문종결되었는데요 이후절차가 어떻게되나요 판결문받을때까지의 기간은 얼마나걸릴까요
# 형사소송 정상참작후 민사소송
# 상간녀 재소송
# 민사소송 중 조정성립이 되어 합의를 하게 됐습니다 이 경우 합의금은 어떻게 받을 수 있나요 또 지정된 날까지 주지 않으면 어떠한 절차를 밟
# 민사소송 변호사
# 민사소송에서 원고가 1심 판결에 불복하여 항소하였지만 시간이 흘러 항소 기각이 된다면 피고는 1심 판결의 위자료를 항소기각된 기간까지 계산해서
#
# 상간남 소송질문
#
# 민사소송은 언제까지 가나요
# 추후 항소이유서 제출시
# 민사소송중인데 상대가 변호사 선임했네요
# 변호사 무료상담하는법좀 알려주세요 손해배상청구소송
# 상간녀 소송을 먼저 했는데
# 변호사  비용  반환 사기 당함 피해자
# 상간남 소송 질문
# 저희집 담이 옆집 땅을 일부차지했다며변호사를 통해 민사소송 소장을 보내 왔습니다 벽만 허물어주고 협의하면 끝인가요 소송비용은 저희가 내는거
# 상간녀의 복수
# 민사소송 준비서면
# 안녕하세요 상간녀소송 진행중인 사람이고 남편이 조정에 참가해서 강제조정이 내려졌지만 원고가 이의신청을해서 변론기일을 앞두고있습니다 저희도 상간남
# 배구팀 학폭 피해자 가해자 상대로 손해배상 민사소송 청구 가능한가요
# 조정기일 출석조정회부로 기일이 지정됬는데요원고 피고 첫 기일입니다 어제였는데 전자소송이라서뒷늦게 알고 참석을 못했습니다 원고 피고 다툼없이 합의로 할거같은데요어제 참석을 못했는데 이런경우 어찌되는지요피고입니다 합의보고싶은데 다시조정기일이 잡히나요자세히좀 알려주세요
# 민사소송 이후 내용증명이 어떤의미가 있을까요
# 소액 민사사건 변호사 사무실 합의서 작성비용
# 민사소송 답변서
# 민사소송 중 변론종결이란 뭐죠 더 이상 준비서면을 제출하지 않아도 된다는 말인가요
# 소액 재판 민사소송 변호사비용 청구범위
# 민사 가집행가압류 의 차이가 뭔가요
# 민사소송 시 변호사가 안내해 주는 범위
# 상간녀위자료청구소송
# 형사와 민사 차이점이 뭔가여
# 유류분반환청구소송요건
# 나홀로 소송 사이트로 민사소송을 진행중인데 증거자료가 대법원 사이트에 올라가지 않아서 등기로 보내려고 합니다
# 변호사님께 질문드려요 제3자 진정서
# 민사소송진행중입니다
# 폭행 민사소송 변호사
# 상간남 소송 관련 질문 입니다
# 가족들 동의하고 상속받은 재산도 유류분반환청구소송이 가능한가요
# 성추행민사소송기간
# 무자녀인 결혼한 딸이 죽게 되면 모친에게 재산분할은 어떤식으로 진행되나요
# 민사소송 당했는데요
# 재판 변론종결
# 가족간 차용증 위조
# 민사소송이요
# 사기피해 민사소송절차
# 사기죄 피해자 민사소송 질문있습니다
# 부당이득금
# 남녀사이가 끝난 후 용돈을 돌려달라고 소송을 하겠다는데 돌려줘야할까요
# 돈받으러 민사소송 내공 100
# 유류분 청구소송에 관해  질문있습니다
# 민사소송 벌금금액도 법원에서 판사가하는건가요원고가 금액을정하는건아니죠
# 소송 중도에 취하하면 변호사에게 지불한 돈은 돌려받지는 못하죠
# 차용증 작성
# 민사소송 고소장 답변
# 민사손해배상 그후 어떻게되죠
# 변론기일 재판서 증인
# 형사처벌 후 민사소송 시효
# 민사소송 소장이 날아왔는데요 답변서 제출
# 민사소송 소장 내용으로 명예훼손 가능여부
# 상간자 위자료청구 재판기록
# 상간자 위자료청구 소송
# 소액민사소송 언제진행되나요
# 양육비 청구소송 강제집행
# 전치 4주 상해 죄 민사소송
# 110만원 정도를 사기를 당했는데 사이버 수사대에 신고를하면 경찰에서 소송을 하는건가요 민사소송도 있던데 이건 제가 따로 해야하는 건가요 그
# 이행권고결정 정본 받았는데
# 소송가액보다 더 많은 금액이 판결될 수 있나요
# 민사 조정 후

# %%
url_t = 'https://kin.naver.com/userinfo/expert/answerList.naver?u=o8vS8mruOuNl00sOdTpwLAZX34LSWpT6MB%2BwLm3h8jQ%3D&page=106'
html = requests.get(url_t)
soup = bs(html.text, 'html.parser')
cotent_soup = soup.find('div', class_='container-fluid-content__right')
cotent_soup.find('tbody', id =  'au_board_list').find_all('tr')
# Out:
# [<tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377921489" rel="KIN">회사강제추행 상대와 잘 정리하고싶은데요....</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.05.</td>
#  </tr>,
#  <tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377829197" rel="KIN">지하철성범죄처벌 어떻게 해결가능한가요?</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.04.</td>
#  </tr>,
#  <tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377828874" rel="KIN">성범죄로펌 쪽으로 알아봅니다.</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.04.</td>
#  </tr>,
#  <tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377828722" rel="KIN">성폭력변호사상담 부터 받고 싶은데요</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.04.</td>
#  </tr>,
#  <tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377828541" rel="KIN">카메라등이용촬영죄경찰조사 상담 요청합니...</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.04.</td>
#  </tr>,
#  <tr>
#  <td class="title">
#  <a href="/qna/detail.naver?d1id=6&amp;dirId=60206&amp;docId=377828218" rel="KIN">성폭행법 관련 상담알아봅니다.</a>
#  </td>
#  <td class="field"><a href="/qna/list.naver?dirId=60206">형사사건</a></td>
#  <td class="t_num tc">2021.01.04.</td>
#  </tr>]
