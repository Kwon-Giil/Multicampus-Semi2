# %%
import pandas as pd
from hanspell import spell_checker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [170], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from hanspell import spell_checker
#
# ModuleNotFoundError: No module named 'hanspell'

# %%
data = pd.read_csv('./data/Total.csv')
data
# Out:
#                                               제목  \
# 0           민사 관련) 차량은 제 명의지만 아버지가 사용, 집은 어머니 명의
# 1                          불기소이유통지 10년뒤 부당이득금 기소
# 2               공증받은 차용증, 민사 청구이의소 관련해서 질문이 있습니다
# 3                       청구이의소송? 채무부존재확인소송 가능할까요?
# 4      사기를 당했는데 피의자가 구치소에 수감이 됬습니다 어떻게 받아내야 하나요ㅠ
# ...                                          ...
# 18492                                상간녀소송 질문이요!
# 18493                   인테리어 시공사 무단침입, 무단촬영 법적조치
# 18494             협박죄로 민사소송을 하려하는데 공소시효가 몇 년인가요?
# 18495                      이런 경우 민사소송으로 해결가능한가요?
# 18496                                    대리수술 고소
#
#                                                       본문  \
# 0      안녕하세요...\n정말 어려운 상황에서 너무나도 힘들어서 질문을 드립니다. 부디 자...
# 1      10년전에 대포통장이로 인해 피해을 봐서 재판결과가 불기소이유통지을 받았거든요\n근...
# 2      연고도 다르고, 일면식도 없는 5살위의 형을, 일을 통해 알게 됐습니다.\n제가 주...
# 3      1) 2010.06.15  이행권고결정(판결)\n2) 2011.05.23  채권압류...
# 4      4천만원정도의 피해가 있고 고소를 했는데 인지사건으로 넘어가서 검찰에서 수사중이었습...
# ...

# %%
data['답변'][15696]
# Out:
# '안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 송재성 입니다.\n상간녀소송 관련 문의하셨습니다.\n상간녀 소송을 위해서는 상간녀가 남편이 유부남인 사실을 인지하고 있어야 합니다. 상간녀가 남편분이 유부남인 사실을 인지한 부분이 관건입니다 \n상간녀에 대하여 위자료 청구소송을 진행하는 경우 상간녀는 통상적으로 외도 사실을 부인하는 것이 보통이므로 소송을 진행하기 전에 관련 증거 수집을 철저하게 해야 합니다. \n반드시 성관계가 있었어야 부정행위에 해당하여 위자료 청구소송을 할 수 있는 것은 아니고 성관계는 없었다고 하더라도 호감을 갖고 정신적인 교류를 나눴다면 충분히 부정한 행위에 해당하여 상간자에게 위자료를 청구할 수 있습니다 법원 역시 각 구체적 사안에 따라서 그 정도와 상황을 참작하여 이를 평가할 수 있다고 언급한 바 있습니다.\n상간녀 소송 청구 금액의 산정의 경우 상간녀가 배우자를 만난 기간, 이혼 여부, 상간녀의 경제력, 사회적 지위, 상간녀의 태도 등에 따라 달라질 수 있습니다\n많은 분들이 오인하시는 부분은 가정법원에 협의이혼의사확인신청서를 제출하거나, 조정신청을 하거나, 재판상 이혼을 청구하여 소를 제기한 경우에 기존의 혼인관계가 이미 종료되었다고 판단하시고 부부간의 정조의무를 지키지 않아도 된다고 생각하신다는 점입니다.\n그러나 어떤 방법으로 혼인관계를 해소하느냐와 무관하게 실질적으로 이혼신고가 되기 전까지는 혼인관계가 해소된 것이 아님에 유의하여야 합니다. \n협의이혼의사확인을 받은 후에는 3개월 이내에 이혼신고를 접수하여야 혼인관계가 해소됩니다. 조정이나 재판의 경우에는 조정성립일 또는 판결일을 기준으로 1개월 이내에 이혼신고를 해야 합니다. \n그러나 협의이혼과는 달리 조정이나 재판의 경우에는 조정이 성립하거나 판결이 내려지면 신고를 하지 않더라도 혼인관계는 해소가 됩니다. 창설적 신고와 보고적 신고의 차이라고 생각하시면 되겠습니다. \n따라서 혼인관계가 법률적으로 완전하게 해소되지 않은 상태에서 질문자님께서 남성분과 교제
# ...

# %%
stopwords = ['보다 자세한 상담이 필요하시면 네임카드의 전화번호나 프로필 사진 클릭 후 기재된 휴대전화번호로 연락주시면 상담을 도와드리겠습니다.'
 ,'보다 자세한 상담을 원하시면 구체적인 내용을 정리하시어 변호사와 직접 상담을 하여 보시기 바라고, 본 변호사와 상담을 원하는 경우 네임카드 기재 연락처로 연락주시면 상담도와드리겠습니다.'
 ,'부담 갖지 마시고 개별적으로 내방을 해주세요. 감사합니다.'
 ,'아래 "네이버 예약 배너"를 통해서 예약을 하셔서 내방을 해주시면, "무료 방문상담"을 진행해 드리겠습니다.'
 ,'(고소장 작성 및 접수/고소유지/24시간 연중무휴/운영 시간 외에도 상담가능)'
 ,'합의 관련 전문 협상팀 및 민사소송 전문 손해배상팀 연계 \n피의(가해) 사건 입장 조언\n반드시 법률적으로 미리 검토 받아서 정확한 피소대응과 관련된 내용에 대해 도움 받으시고, \n이에 대해 면담이 필요하신 부분이 있다면 언제든지 연락을 주시기 바랍니다\n(경찰 및 검찰조사 즉각 동행, 재판 및 공판 대비/소송전략 즉각 수립 및 대응/ 24시간 연중무휴/운영 시간 외에도 상담가능)'
 ,'변호사와 의뢰인을 더 가까이, 로톡'
 ,'지식iN 변호사 답변은 로톡과 네이버의 콘텐츠 제휴를 통해 변호사가 직접 정확하고 신뢰할 수 있는 답변을 전달해 드립니다.'
 ,'로톡은 법무법인이나 법률사무소가 아니며, 법률사무를 제공하지 않습니다. 모든 법률상담은 로톡을 이용하는 각 변호사 회원이 직접, 독립적으로 수행합니다.'
 ,'더 많은 변호사 답변 보기'
 ,'좀 더 자세한 상담을 원하신다면, 하단의 네임카드를 이용하여 상담을 신청해주시면 언제든 상담이 가능합니다.'
 ,'변호사 김 상 철 올림'
 ,'답변 변호사와의 상담을 원하신다면, 아래의 사무실 연락처로 전화문의 하시거나, [변호사 프로필보기]를 눌러보세요.'
 ,'사무실 문의 전화: 050-7725-2770\n- [변호사 프로필보기] < 클릭'
 ,'https://www.lawtalk.co.kr/qna/212532'
 ,'답변하신 변호사님과 상담을 원하신다면, 지금 로톡 (https://www.lawtalk.co.kr)에 방문해보세요! [변호사와 상담하기]'
 ,'질문에 대한 답변은 한정된 정보에 근거하여 드리는 답변이기 때문에 보다 정확한 상담은 구체적인 내용과 상황에 따라 달라질 수 있습니다.'
 ,'연락주시기 바랍니다 010-9929-9997'
 , '직접 "네이버 엑스퍼트"상담 및 "로톡"에서 구체적인 심층 법률상담을 진행하고 있습니다.'
 , '혹시 사안과 관련해 좀 더 구체적인 상담을 원하시면 각 분야별로 [네이버 엑스퍼트 비밀유지 전화상담 신청] [로톡 비밀유지 전화상담 신청]을 통해 확실하게 정리를 하실 수 있습니다.'
 , '네이버 엑스퍼트 법률사안 검토요청 URL : https://m.expert.naver.com/mobile/expert/product/detail?storeId=100026095&productId=100054782'
 , '로톡 법률사안 검토요청 URL : https://www.lawtalk.co.kr/directory/profile/2249-%EA%B9%80%EC%A7%80%EC%A7%84?rzbt=a'
 , '변호인 선임여부에 대한 판단이 잘 서지 않을 때 또는 그냥 단순히 사안에 대해 좀 더 구체적인 법률상담이 필요할 때 언제든지 모두 환영이니,'
 , '필요하신 분들은 적극적으로 요청해주시고 이용해주시면 감사하겠습니다.'
 , '구체적인 내용 및 절차는 아래 링크를 통해 상담받아보시기 바랍니다.'
 , '엑스퍼트 PC 버전 접속 URL : https://m.kin.naver.com/profile/index.nhn?u=a%2B9nsi8b7DQx0LQ4A1EofA8azPRdZsDGh6pbxvJSvFI%3D'
 ,  '엑스퍼트 모바일 버전 접속 URL : https://m.kin.naver.com/profile/index.nhn?u=a%2B9nsi8b7DQx0LQ4A1EofA8azPRdZsDGh6pbxvJSvFI%3D'
 , '아래 "네이버 예약 배너"를 통해서 방문예약을 하셔서 내방을 해주셔도 됩니다. <방문상담은 유료로 진행이 됩니다>'
 , '부담 갖지 마시고 개별적으로 내방을 해주시면 실질적인 법률적 도움을 드릴 수 있도록 하겠습니다.'
 , '고소(피해) 사건 입장 조언'
 , '반드시 법률적으로 미리 검토 받아서 정확한 고소진행과 관련된 내용에 대해 도움 받으시고,'
 , '이에 대해 면담이 필요하신 부분이 있다면 언제든지 연락을 주시기 바랍니다'
 , '(고소장 작성 및 접수/고소유지/24시간 연중무휴/운영 시간 외에도 상담가능).'
 , '합의 관련 전문 협상팀 및 민사소송 전문 손해배상팀 연계'
 , '피의(가해) 사건 입장 조언'
 , '반드시 법률적으로 미리 검토 받아서 정확한 피소대응과 관련된 내용에 대해 도움 받으시고,'
 , '이에 대해 면담이 필요하신 부분이 있다면 언제든지 연락을 주시기 바랍니다'
 , '(경찰 및 검찰조사 즉각 동행, 재판 및 공판 대비/소송전략 즉각 수립 및 대응/ 24시간 연중무휴/운영 시간 외에도 상담가능).' 
 , '안녕하세요. 네이버 법률과 함께 지식iN 법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '안녕하세요. Pray4U! 질문자님을 위해 기도하는, 법무법인 감사합니다, 입니다.'
 , '안녕하세요. 네이버 지식iN 법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '안녕하세요. 네이버 법률과 함께 지식iN 법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '다만, 사해행위 취소 소송은 “난이도(難易度)”가 매우 높은 소송입니다. 수술에 비유하자면, “뇌수술”과 비슷합니다. 반드시 전문 변호사를 선임하셔서 진행해야 합니다.'
 , '안녕하세요.네이버 법률과 함께지식iN 법률상담을 진행하고 있는송명호 변호사입니다.'
 , 'ㅁㅁ안녕하세요. 네이버 법률과 함께 지식iN 법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '안녕하세요. 로시컴과 함께 지식iN 법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '안녕하세요. 로시컴과 함께 지식iN법률상담을 진행하고 있는 송명호 변호사입니다.'
 , '대전변호사 유성권 변호사 사시52회입니다.'
 , '대전고소전문변호사 유성권 변호사 사시52회입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담변호사 유성권 입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담변호사 장종현 입니다.'
 , '안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 장종현 입니다.'
 , '감사합니다.로시컴과 함께 지식iN법률상담을 진행하고 있는 채권추심 전문 변호사(대한변협 제2014-10호), 송명호 변호사입니다.'
 , '안녕하세요. 서울지방변호사회-네이버 지식iN 상담 변호사 이종걸 입니다.'
 , '안녕하세요. 서울지방변호사회-네이버 지식iN 상담변호사 이종걸 입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담변호사 김호제 입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담 김호제 법률사무소 입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담변호사 이종윤 입니다.'
 , '안녕하세요. 로시컴-네이버 지식iN 상담변호사 이종윤 입니다.'
 , '답변 중 입니다 안녕하세요. 로시컴-네이버 지식iN 상담변호사 이종윤 입니다.'
 , '네이버 절대신 송명호 변호사와 직접 상담할 수 있는 기회 네이버 예약”https://booking.naver.com/booking/13/bizes/179102 을 통해서 예약 후 방문해주시면 더 자세한 상담 가능합니다.'
 , '네이버 절대신 송명호 변호사와 직접! 신속히!' 
 , '상담할 수 있는 네이버 엑스퍼트”https://m.kin.naver.com/profile/index.nhn?u=dHzxuCavu8ienakzxCrEdG9FOUDPn0E7cdJxCHNVSkE%3D를 통해서 변호사와 직접! 신속하게! 엑스퍼트 유료 상담도 가능합니다.#이혼#상속#가사법#채권추심#변호사#법률상담#네이버예약'
 , '네이버 절대신 송명호 변호사와 직접 상담할 수 있는 기회 네이버 예약”https://booking.naver.com/booking/13/bizes/179102 을 통해서 예약 후 방문해주시면 더 자세한 상담 가능합니다.'
 , '#이혼#상속#가사법#채권추심#변호사#법률상담#네이버예약'
 , '#채권추심#이혼#상속#가사법#변호사#법률상담#네이버예약'
 , 'nhn?u=dHzxuCavu8ienakzxCrEdG9FOUDPn0E7cdJxCHNVSkE%3D'
 , '#이혼#상속#가사법#변호사#법률상담#네이버예약'
 , '#이혼#상속#가사법#변호사#법률상담#네이버예약'
 , '송명호 변호사'
 , '너무 걱정하지 마시고 개별적으로 문의를 주시면 관련된 부분에 대해 구체적으로 상담 및 고소 및 피소 대응전략을 짜서 대비를 하는데 도움을 드릴 수 있도록 하겠습니다.'
 , '법률사무소가연'
 , '대전손해배상청구소송전문변호사'
 , '대전소송비용변호사'
 , '대전공유자소송변호사'
 , '대전민사소송변호사'
 , '위 내용은 제 블로그 승소사례에서 퍼온 글입니다.'
 , '대전변호사'
 , '카톡아이디'
 , '블로그']

# %%
# 법무법인 법승 제거
indexs = data[15808:15827].index
data.drop(indexs, inplace=True)

indexs = data[16673:16732].index
data.drop(indexs, inplace=True)

indexs = data[18468:18487].index
data.drop(indexs, inplace=True)

indexs = data[16993:17141].index
data.drop(indexs, inplace=True)

data.reset_index(drop=True, inplace=True)

# %%
# 마지막 두 문장 제거
def last_two_del(text):
    texts = text.split('.')[:-2]
    text = '.'.join(texts)
    return text

# 첫 두 문장 제거
def first_two_del(text):
    texts = text.split('.')[2:]
    text = '.'.join(texts)
    return text

# %%
df = data.copy()

# %%
indexs_1 = df[df['답변'].str.contains('송재성')].index
temp_1 = df.loc[indexs_1]

indexs_2 = df[258:553].index
temp_2 = df.loc[indexs_2]

indexs_3 = df[1526:1808].index
temp_3 = df.loc[indexs_3]

df.drop(indexs_1, inplace=True)
df.drop(indexs_2, inplace=True)
df.drop(indexs_3, inplace=True)
temp_df = pd.concat([temp_1, temp_2, temp_3]).reset_index(drop=True)

temp_df['답변'] = temp_df['답변'].apply(last_two_del)

df = pd.concat([df, temp_df]).reset_index(drop=True)

# %%
df['답변'] = df['답변'].apply(first_two_del)

# %%
step_1 = df.copy()
step_1
# Out:
#                                               제목  \
# 0           민사 관련) 차량은 제 명의지만 아버지가 사용, 집은 어머니 명의
# 1                          불기소이유통지 10년뒤 부당이득금 기소
# 2               공증받은 차용증, 민사 청구이의소 관련해서 질문이 있습니다
# 3                       청구이의소송? 채무부존재확인소송 가능할까요?
# 4      사기를 당했는데 피의자가 구치소에 수감이 됬습니다 어떻게 받아내야 하나요ㅠ
# ...                                          ...
# 18266            통장 압류를 하려고 하는데 하는 방법좀 알려주세요 ㅠㅠㅠ
# 18267                           민사 재판 부모님집 거주 압류
# 18268                민사소송 항소 이유를 잘못 썼는데요.별일 없겠죠?
# 18269       민사소송 소장에 소송비용은 피고가 부담한다는 내용을 빠트렸습니다.
# 18270                      이름을 모르는 사람에게 폭행을 당했을때
#
#                                                       본문  \
# 0      안녕하세요...\n정말 어려운 상황에서 너무나도 힘들어서 질문을 드립니다. 부디 자...
# 1      10년전에 대포통장이로 인해 피해을 봐서 재판결과가 불기소이유통지을 받았거든요\n근...
# 2      연고도 다르고, 일면식도 없는 5살위의 형을, 일을 통해 알게 됐습니다.\n제가 주...
# 3      1) 2010.06.15  이행권고결정(판결)\n2) 2011.05.23  채권압류...
# 4      4천만원정도의 피해가 있고 고소를 했는데 인지사건으로 넘어가서 검찰에서 수사중이었습...
# ...

# %%
import re

def clean_text(text):
    text = re.sub(r'[@%\\*=()/~&\+á?\xc3\xa1\-\|\:\;\!\-\,\_\~\$\'\"\“]', '', text) #remove punctuation 
    text = re.sub(r'\.\.+', '.', text) #점이 두 개 이상 반복되는 부분 제거
    text = re.sub(r'\u200B', '', text) #폭 없는 공백 제거
    text = text.lower() #lower case 
    text = re.sub(r'\s+', ' ', text) #remove extra space 
    text = re.sub(r'<[^>]+>','',text) #remove Html tags
    text = re.sub(r'\s+', ' ', text) #remove spaces
    text = re.sub(r"^\s+", '', text) #remove space from start 
    text = re.sub(r'\s+$', '', text) #remove space from the end
    text = re.sub(r'\.', '', text) #점 제거
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', text)
    text = re.sub('[ +]', " ", text)
    text = re.sub("\n", " ", text)
    text = re.sub("[A-Za-z]", "", text)
    text = re.sub('[0-9]', '', text)
    return text

def spell_check(text):
    text = spell_checker.check(text).as_dict()["checked"]
    return text

def clean_stopwords(text):
    for stopword in stopwords:
        text = re.sub(f'{stopword}', '', text)
    return text

def preprocess(text):
    text = clean_stopwords(sen)
    text = celan_text(sen)
    text = spell_check(sen)
    return text

# %%
for stopword in stopwords:
    try:
        text = re.sub(f'{stopword}', '', text)
    except:
        print(stopword)

# %%
step_2 = df.copy()
step_2
# Out:
#                                               제목  \
# 0           민사 관련) 차량은 제 명의지만 아버지가 사용, 집은 어머니 명의
# 1                          불기소이유통지 10년뒤 부당이득금 기소
# 2               공증받은 차용증, 민사 청구이의소 관련해서 질문이 있습니다
# 3                       청구이의소송? 채무부존재확인소송 가능할까요?
# 4      사기를 당했는데 피의자가 구치소에 수감이 됬습니다 어떻게 받아내야 하나요ㅠ
# ...                                          ...
# 18266            통장 압류를 하려고 하는데 하는 방법좀 알려주세요 ㅠㅠㅠ
# 18267                           민사 재판 부모님집 거주 압류
# 18268                민사소송 항소 이유를 잘못 썼는데요.별일 없겠죠?
# 18269       민사소송 소장에 소송비용은 피고가 부담한다는 내용을 빠트렸습니다.
# 18270                      이름을 모르는 사람에게 폭행을 당했을때
#
#                                                       본문  \
# 0      안녕하세요...\n정말 어려운 상황에서 너무나도 힘들어서 질문을 드립니다. 부디 자...
# 1      10년전에 대포통장이로 인해 피해을 봐서 재판결과가 불기소이유통지을 받았거든요\n근...
# 2      연고도 다르고, 일면식도 없는 5살위의 형을, 일을 통해 알게 됐습니다.\n제가 주...
# 3      1) 2010.06.15  이행권고결정(판결)\n2) 2011.05.23  채권압류...
# 4      4천만원정도의 피해가 있고 고소를 했는데 인지사건으로 넘어가서 검찰에서 수사중이었습...
# ...

# %%
step_2['답변'] = step_2['답변'].apply(clean_text)
step_2['답변'] = step_2['답변'].apply(clean_stopwords)
# step_2['답변'] = step_2['답변'].apply(spell_check)

step_2['본문'] = step_2['본문'].apply(clean_text)
# step_2['질문'] = step_2['질문'].apply(spell_check)

step_2.drop(['제목'], axis=1, inplace=True)
step_2.to_csv('prep_data.csv', encoding='utf-8', index=False)

# %%
step_2['답변'][4]
# Out:
# '가해자가 위 사건으로 구속기소 되었다면 가해자를 피고로 하여 민사소송 및 강제집행으로 피해액을 변제받을 수 있습니다      '
