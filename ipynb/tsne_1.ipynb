# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab_light_220429.sh

# %%
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from konlpy.tag import Mecab

# %%
df = pd.read_csv('./data/Textranked.csv')
df
# Out:
#                                                 Question  \
# 0      정말 어려운 상황에서 너무나도 힘들어서 질문을 드립니다. 아버지가 제 명의로 사업자...
# 1      년 전에 대포 통장이로 인해 피해를 봐서 재판 결과가 불기소 유통 지을 받았거든요....
# 2      제 계좌로 입금을 했다던가 그런부분 전혀없이 그 형의 계좌로 그 형의 공인인증서를 ...
# 3      채권시효년 소멸로 본다면 어떤 대응이 가능할지 여쭤봅니다 지인에게 연대보증 해줬는데...
# 4       그 와중에 피의자와 어떻게 연락이 닿게 되어서 갚겠다는 의사를 보였고 정말 적은 ...
# ...                                                  ...
# 18160  제가 작년 월쯤 승소 판결 받은 후에 압류 절차를 진행을 해야 하는데 혼자 스스로 ...
# 18161                     민사재판 패소 후 현재 등본은 부모님댁으로 되어있습니다
# 18162  이에 원고인에게 원룸계약서 제출을 요구합니다 라고 썼거든요.거기보니 원고측에서 이미...
# 18163   오늘 피고 측에서 답변서를 받고 변론 기일이 정해졌는데 이제 보니 제가 작성한 소...
# 18164  경찰서에 신고해서 상대방이 벌금을 낸 거까지는 아는데 제 위자료나 병원비 같은 거 ...
#
#                                                   Answer
# 0      차량의 경우 현재 점유자인 아버지를 피고로 하여 차량 인도 청구소송 및 차량 점유 ...
# 1             소장 내용에 대한 검토가 필요하므로 소장을 지참하고 상담을 받으시기 바랍니다
# 2      별도의 구체적 상담이 필요하나 실제 채무가 없음에도 공증을 가지고 채권자가 강제집행...
# 3      별도의 구체적 상담이 필요하나 이행 권고 결정은 기판력의 제한이 없으므로 소멸시효 ...
# 4      가해자가 위 사건으로 구속 기소되었다면 가해자를 피고로 하여 민사소송 및 강제집행으...
# ...                                                  ...
# 18160   여쭤보신 것은 통장 압류 절차인 것으로 보입니다 통장 압류의 법률적 용어는 예금채...
# 18161  민사소송 패소 후 부모님 집에 압류가 들어올 수 있는지와 관련하여 질문하셨습니다.민...
# 18162   따라서 각 월 차임 채권은  년에 발생한 경우 년이 경과한  년 사이에 이미 시효...
# 18163  민사소송 소장에 소송비용 청구를 빠드린 경우와 관련하여 질 무하셨습니다. 민사소송에...
# 18164   그리고 해당 관할 검찰청 가셔서 본인이 피해자인데 가해자에 대한 폭행 사건 번호를...
#
# [18165 rows x 2 columns]

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

# %%
mecab = Mecab()
q_pos = []

for i in range(len(df)):
    q_pos.append(mecab.pos(df['Question'][i]))
df['q_tokens'] = q_pos

pos = ["NNG","NNP","VV","VA"]

df['q_tokens'] = df['q_tokens'].apply(lambda x: [t for (t, p) in x if p in pos])

# %%
df_q = df['q_tokens']

# %%
model = Word2Vec(sentences=df_q, size=128, window=5, min_count=5, workers=4, sg=0)

# %%
model.wv.vectors[0]
# Out:
# array([ 0.44041914,  0.44604036, -0.16217443,  0.14147988,  0.11388998,
#        -0.7265413 ,  0.49893975,  0.51626945, -0.3465576 ,  0.02880786,
#        -0.15027289, -0.1332341 , -0.18544893, -0.01165699, -0.65233445,
#         0.27379766,  0.30150318,  0.3043063 , -1.0717638 ,  0.4048394 ,
#        -0.22896703,  0.26144177,  0.19170684,  0.38349965,  0.22635247,
#         0.2577132 , -0.01418872, -0.17291553, -0.2340726 , -0.11401936,
#         0.05878815, -0.10683084, -0.49512914, -0.41203883,  0.27576253,
#         0.23105536, -0.303962  ,  0.1614181 , -0.6889687 ,  0.02939563,
#        -0.13760424, -0.5363465 ,  0.13301377, -0.00846929,  0.31664577,
#        -0.17052066, -0.48894185,  0.11455227, -0.7380791 , -0.05059787,
#        -0.69660497,  0.0318298 , -0.07948267,  0.24973473,  0.66446173,
#         0.19255233, -0.3833207 ,  0.12134778, -0.18567508,  0.00326678,
#         0.05450306, -0.1571112 , -0.01120736, -0.34184197,  0.06097202,
#        -0.07282836, -0.3431122 ,  0.08787067, -0.02984847,  0.28539634,
#         0.8236339 ,  0.15172552,  0.09318743,  0.32208765,  0.16485456,
#        -0.4034019 ,  0.03258234,  0.2279767 , -0.4032846 , -0.02214371,
#         0.01121099,  0.1774481 , -0.60482377,  0.15606794, -0.08012319,
#        -0.2828069 , -0.0599388 ,  0.29224882, -0.45702225, -0.4886124 ,
#         0.27183354,  0.16876933,  0.19863968, -0.55088174, -0.2014671 ,
#        -0.39066738,  1.1702027 , -0.39862344, -0.35456848, -0.10502179,
#         0.5060818 ,  0.00779609,  0.08247136, -0.00290764, -0.7553791 ,
#        -0.51293427,  0.42980656,  0.19689654,  0.25060815,  0.11148065,
#         0.26113436, -0.16919209, -0.32886103, -0.20282009,  0.13116015,
#        -0.09388013, -0.2889338 , -0.13034913, -0.14069669,  0.40444735,
#         0.02736359, -0.09110845,  0.82534164, -0.20174386, -0.18547086,
#        -0.3934104 ,  0.29545036,  0.3341281 ], dtype=float32)

# %%
k = 20
kmeans = KMeans(n_clusters=k, random_state = 2022)
y_pred = kmeans.fit_predict(model.wv.vectors)

tsne = TSNE(n_components = 2, perplexity = 100, random_state = 2022)
X_embedded = tsne.fit_transform(model.wv.vectors)

sns.set(rc={'figure.figsize':(15,15)})
palette = sns.hls_palette("ch:s=.25,rot=-.25", as_cmap=True) 
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred,
                legend='full', palette=palette)

plt.title('Question t-SNE with KMeans Labels')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
